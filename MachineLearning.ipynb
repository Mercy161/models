# %% [markdown]
# <font color='red'>$\Huge{\textbf{School of Computational Techniques}}$
# $\Huge{\textbf{for Physics Students in Kenya}}$
#
# $\Huge{\text{Machine Learning Techniques}}$
#
# Lorenzo Capriotti,
# Wanjiku Nganga

# %% [markdown]
# # <font color='red'>**Introduction to Machine Learning**

# %% [markdown]
# ##**Data analysis and visualisation with Python**

# %%
import numpy as np
from matplotlib import pyplot
x = np.linspace(0, 4, 100)
y = np.sin(3*x)
pyplot.plot(x, y)
#pyplot.show()

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
pyplot.plot(xs, ys,'o')
pyplot.show()

# %% [markdown]
# ##**Machine Learning tools: `TensorFlow` and `Keras`**
#
#
#
#
# ---

# %%
# !pip install tensorflow_decision_forests
# !python -m pip install scikeras
# !python -m pip install np_utils
# Out:
# Collecting tensorflow_decision_forests
#   Downloading tensorflow_decision_forests-1.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (2.0.3)
# Collecting tensorflow~=2.16.1 (from tensorflow_decision_forests)
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (0.43.0)
# Collecting wurlitzer (from tensorflow_decision_forests)
#   Downloading wurlitzer-3.1.1-py3-none-any.whl (8.6 kB)
# Collecting tf-keras~=2.16 (from tensorflow_decision_forests)
#   Downloading tf_keras-2.16.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.6 MB/s eta 0:00:00
# Collecting ydf (from tensorflow_decision_forests)
#   Downloading ydf-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.5 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (1.64.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 73.1 MB/s eta 0:00:00
# Collecting keras>=3.0.0 (from tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.16.1->tensorflow_decision_forests) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2024.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests) (13.7.1)
# Collecting namex (from keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.16.1->tensorflow_decision_forests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.16.1->tensorflow_decision_forests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.16.1->tensorflow_decision_forests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.16.1->tensorflow_decision_forests) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tensorflow_decision_forests) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tensorflow_decision_forests) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tensorflow_decision_forests) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tensorflow_decision_forests) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow~=2.16.1->tensorflow_decision_forests) (0.1.2)
# Installing collected packages: namex, ydf, wurlitzer, optree, ml-dtypes, h5py, tensorboard, keras, tensorflow, tf-keras, tensorflow_decision_forests
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
#   Attempting uninstall: tf-keras
#     Found existing installation: tf_keras 2.15.1
#     Uninstalling tf_keras-2.15.1:
#       Successfully uninstalled tf_keras-2.15.1
# Successfully installed h5py-3.11.0 keras-3.3.3 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow_decision_forests-1.9.1 tf-keras-2.16.0 wurlitzer-3.1.1 ydf-0.5.0
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.3.3)
# Collecting scikit-learn>=1.4.2 (from scikeras)
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Installing collected packages: scikit-learn, scikeras
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikeras-0.13.0 scikit-learn-1.5.0
# Collecting np_utils
#   Downloading np_utils-0.6.0.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from np_utils) (1.25.2)
# Building wheels for collected packages: np_utils
#   Building wheel for np_utils (setup.py) ... done
#   Created wheel for np_utils: filename=np_utils-0.6.0-py3-none-any.whl size=56441 sha256=d6766d9824f08f970455148c749fa7ab6241b0ba3cdeeb27353dcea310181d2a
#   Stored in directory: /root/.cache/pip/wheels/b6/c7/50/2307607f44366dd021209f660045f8d51cb976514d30be7cc7
# Successfully built np_utils
# Installing collected packages: np_utils
# Successfully installed np_utils-0.6.0

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
model.fit(xs, ys, epochs=50)

next = np.array([10,15,20])
next_prediction = model.predict(next)
for i,val in enumerate(next):
  print("Prediction for %f: %f" % (val, next_prediction[i]))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 21.6518
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 17.0522
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 13.4331
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 10.5854
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.3446
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.5814
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.1938
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 4.1017
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.2423
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.5658
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.0332
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.6140
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2838
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0237
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8189
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6574
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5301
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4297
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3504
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2878
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2383
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1991
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1680
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1434
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1237
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1080
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0955
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0854
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0772
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0706
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0652
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0607
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0570
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0539
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0513
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0491
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0471
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0454
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0439
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0425
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0413
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0402
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0391
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0381
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0372
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0363
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0355
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0347
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0339
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Prediction for 10.000000: 31.482563
# Prediction for 15.000000: 46.843739
# Prediction for 20.000000: 62.204914
# <ipython-input-4-e25f3cc36175>:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Prediction for %f: %f" % (val, next_prediction[i]))

# %% [markdown]
# ---
#
# This looks fantastic, but the relation between x and y is very simple in this case - just a linear dependence. What happens when we have a much more complicated situation? Let's have a look at a more complex function: $f(x) = 0.1\cdot x \cdot \cos(x)$
#
# ---

# %%
import math
# Create data
x_data = np.linspace(-10, 10, num=1000) #get an array of 1000 numbers evenly spaced
y_data = 0.1*x_data*np.cos(x_data)
print('Data created successfully')
pyplot.clf()
pyplot.plot(x_data, y_data,'o')
pyplot.show()

# Create the model
model = keras.Sequential()
model.add(keras.layers.Dense(units = 1, activation = 'linear', input_shape=[1]))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 1, activation = 'linear'))
model.compile(loss='mse', optimizer="adam")


model.fit( x_data, y_data, epochs=1000, verbose=1)
# Out:
# Data created successfully
# Epoch 1/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.7462
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1830
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1820
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1699
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1814
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1683
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1884
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1780
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1681
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1668
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1861
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1700
# Epoch 13/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1658
# Epoch 14/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1727
# Epoch 15/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1636
# Epoch 16/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1801
# Epoch 17/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1614
# Epoch 18/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1628
# Epoch 19/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1665
# Epoch 20/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1466
# Epoch 21/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1434
# Epoch 22/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1437
# Epoch 23/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1383
# Epoch 24/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1390
# Epoch 25/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1335
# Epoch 26/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1254
# Epoch 27/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1192
# Epoch 28/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1130
# Epoch 29/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1050
# Epoch 30/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1026
# Epoch 31/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0930
# Epoch 32/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0910
# Epoch 33/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0973
# Epoch 34/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0791
# Epoch 35/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0905
# Epoch 36/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0765
# Epoch 37/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0727
# Epoch 38/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0692
# Epoch 39/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0636
# Epoch 40/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0574
# Epoch 41/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0608
# Epoch 42/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549
# Epoch 43/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0458
# Epoch 44/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0382
# Epoch 45/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0402
# Epoch 46/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0309
# Epoch 47/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0301
# Epoch 48/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0289
# Epoch 49/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0275
# Epoch 50/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0201
# Epoch 51/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193
# Epoch 52/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231
# Epoch 53/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 54/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171
# Epoch 55/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0135
# Epoch 56/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0111
# Epoch 57/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109
# Epoch 58/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0075
# Epoch 59/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088
# Epoch 60/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100
# Epoch 61/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084
# Epoch 62/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067
# Epoch 63/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0080
# Epoch 64/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0
1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5579e-04
# Epoch 919/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6274e-04
# Epoch 920/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4590e-04
# Epoch 921/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3835e-04
# Epoch 922/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1529e-04
# Epoch 923/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9596e-04
# Epoch 924/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2137e-04
# Epoch 925/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8350e-05
# Epoch 926/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7558e-04
# Epoch 927/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5734e-05
# Epoch 928/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3765e-04
# Epoch 929/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4438e-04
# Epoch 930/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4827e-04
# Epoch 931/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3188e-05
# Epoch 932/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1647e-04
# Epoch 933/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1716e-04
# Epoch 934/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6956e-04
# Epoch 935/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0454e-05
# Epoch 936/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1440e-04
# Epoch 937/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3043e-04
# Epoch 938/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0048e-04
# Epoch 939/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1201e-04
# Epoch 940/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5988e-04
# Epoch 941/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0464e-04
# Epoch 942/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0475e-04
# Epoch 943/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3298e-04
# Epoch 944/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0841e-04
# Epoch 945/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0067e-04
# Epoch 946/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4542e-04
# Epoch 947/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2071e-04
# Epoch 948/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1157e-04
# Epoch 949/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5521e-04
# Epoch 950/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3678e-04
# Epoch 951/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8417e-04
# Epoch 952/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5796e-04
# Epoch 953/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2440e-04
# Epoch 954/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7170e-04
# Epoch 955/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7573e-04
# Epoch 956/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5343e-04
# Epoch 957/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0736e-04
# Epoch 958/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0966e-04
# Epoch 959/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9188e-05
# Epoch 960/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5147e-04
# Epoch 961/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1924e-04
# Epoch 962/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7400e-04
# Epoch 963/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8013e-04
# Epoch 964/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2225e-04
# Epoch 965/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3428e-04
# Epoch 966/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2884e-04
# Epoch 967/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3175e-04
# Epoch 968/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1137e-04
# Epoch 969/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6586e-05
# Epoch 970/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6039e-05
# Epoch 971/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2033e-04
# Epoch 972/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6817e-04
# Epoch 973/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4258e-04
# Epoch 974/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3669e-04
# Epoch 975/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5082e-05
# Epoch 976/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8330e-04
# Epoch 977/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5427e-04
# Epoch 978/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2672e-04
# Epoch 979/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9006e-05
# Epoch 980/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7952e-05
# Epoch 981/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3962e-04
# Epoch 982/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0074e-04
# Epoch 983/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5614e-05
# Epoch 984/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1309e-04
# Epoch 985/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2653e-04
# Epoch 986/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0756e-04
# Epoch 987/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3899e-04
# Epoch 988/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8756e-04
# Epoch 989/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5512e-04
# Epoch 990/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8776e-04
# Epoch 991/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5327e-04
# Epoch 992/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 993/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7007e-04
# Epoch 994/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2040e-04
# Epoch 995/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1987e-04
# Epoch 996/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9457e-05
# Epoch 997/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5122e-04
# Epoch 998/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7167e-04
# Epoch 999/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9778e-05
# Epoch 1000/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3469e-05

# %%
# "predict" the model on the same data you used (i.e. look at the output of the model)
y_predicted = model.predict(x_data)

# Display the result
pyplot.clf()
pyplot.plot(x_data, y_data, "o")
pyplot.plot(x_data, y_predicted, 'r', linewidth=4)
pyplot.grid()
pyplot.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ---
#
# Try to repeat the same excercise by adding some noise to your data (i.e. add the term `0.1*np.random.normal(size=1000)` to your `y_data` and train your neural network again.
#
# ---

# %% [markdown]
# # <font color='red'>**First application: Near InfraRed (NIR) spectra classification using Principal Components (PC) analysis**

# %%
xi = []
yi = []

xi.append([23.471052, 22.288738, 23.00626, 21.713207, 22.364569,
         23.80996, 24.568117, 23.014803, 24.373678, 23.43715,
         23.981203, 24.353722, 23.550165, 23.684776, 23.528128,
         25.52674, 26.837715, 27.073944, 25.791689, 22.950403,
         25.367786, 24.513708, 23.527008, 23.38879, 25.007792,
         23.18345, 22.191957, 22.801744, 24.195189, 24.973558,
         24.70202, 26.258934, 24.35663, 24.036402, 25.241417,
         26.914028, 25.358839, 24.137556, 23.85375, 23.255384,
         24.46996, 22.674728, 23.53211, 23.020061, 23.688265,
         21.731178, 24.155262, 23.20795, 24.586775, 23.659552])

xi.append([6.5605283, 5.843193, 5.5454907, 6.3776884, 7.912208,
         10.535438, 10.867968, 10.732018, 13.2167225, 12.868343,
         10.400907, 10.051826, 10.5186615, 9.494503, 9.686136,
         6.6113744, 6.2099056, 7.4366293, 7.825457, 5.588935,
         9.849091, 13.163032, 15.968322, 13.12406, 13.171037,
         9.939608, 11.994316, 7.41287, 6.2874303, 5.5078607,
         4.504227, 3.3024523, 5.1489177, 10.3479595, 10.696899,
         15.538159, 12.387533, 13.650082, 12.895711, 11.77942,
         8.205831, 8.872327, 16.634415, 7.9342365, 3.1016684,
         3.463665, 4.30421, 2.9773977, 2.410612, 4.321653])

xi.append([3.8438551, 2.4657202, 1.6996317, 5.088206, 4.6542497,
         4.930853, 4.7855034, 4.8559117, 2.5145917, 5.04357,
         3.8898096, 4.85669, 5.1863155, 4.1168633, 5.313662,
         4.485993, 4.277309, 5.7306023, 2.973297, 2.4928844,
         4.5306854, 4.5779557, 3.3641057, 5.027289, 5.1512256,
         4.8021226, 4.4917283, 5.1750746, 3.858354, 5.45908,
         6.4158473, 4.467482, 4.776676, 4.9854007, 4.259277,
         5.5492997, 6.0477157, 5.294147, 4.9666414, 4.804935,
         2.6862493, 5.8809433, 5.557285, 5.912971, 7.2545934,
         5.276486, 4.2882485, 4.723774, 4.7287574, 3.1080692])

xi.append([-5.328447, -5.1206293, -3.207903, -4.5476823, -0.27227813,
         -0.6431728, -1.3071129, -0.7069455, 4.226158, 3.451721,
         0.76020676, 3.7205317, 0.50605243, 0.005223486, -1.6045525,
         -1.9145719, -2.4964252, -1.8143132, -0.82459563, 0.3860829,
         -1.2509724, -0.88833976, -2.6889126, -2.266193, -3.358301,
         -2.2653172, 0.002179503, -2.317467, -1.1950157, 0.5792958,
         -0.6040423, -0.8325319, -1.4210206, -0.4443239, -1.6967925,
         -0.6396385, -0.6128616, -2.7023213, 0.46657744, -0.9178785,
         -0.2877001, 0.4266316, -0.56158394, -1.1378384, 0.571318,
         -1.0004925, -0.112096995, -0.44398528, -0.0044041253, -0.8330042])

xi.append([0.9587121, 0.30856496, 1.8157008, 0.8386025, 0.4135167,
         1.9904915, 0.98597133, 1.8690081, 0.3293129, 0.81704545,
         2.5308337, 2.4057667, -0.22907631, 0.63380474, 0.5268966,
         2.449347, 4.843279, 5.0096097, 2.2973752, 4.5572495,
         3.4573522, 3.014826, 1.8734821, 3.404176, 2.1541958,
         1.1659911, 1.3945819, -0.26818445, 0.98057336, 4.908574,
# Writing your data directly in your script files (or notebook) is usually not a great idea. It is better to detach them and put them in a separate file - we will do this later. For now, let's have a look at how these points distribute within the space of the first two principal components.
#
# ---

# %%
from matplotlib import pyplot
pyplot.clf()
labplot = ["0/8 Milk","1/8 Milk","2/8 Milk", "3/8 Milk", \
"4/8 Milk", "5/8 Milk","6/8 Milk","7/8 Milk", "8/8 Milk"]

for i,x in enumerate(xi):
  pyplot.plot(xi[i],yi[i],"o")

pyplot.xlabel('PC1')
pyplot.ylabel('PC2')
pyplot.legend(labplot,loc='upper right')
pyplot.title('Principal Component Analysis of Milk NIR Data')
pyplot.show()

# %% [markdown]
# ---
#
# It looks they are all quite localised in separate regions, apart from some small overlap in a few places.
#
#
# Now, for the data storage. What we had above is highly unpractical, unreadable and prone to several errors. A much better way to deal with datasets is to import them from an external file. One of the most used extension today is `csv` files, which are text files where the values are separated by a comma and the different entries are in different coloumns - like a big table. Easy to produce (several softwares, like Microsoft Excel, will convert their data format to csv), easy to store and easy to read! Let's see how to write a csv file using the dataset above, and then let's ignore what we already have and read our data from the file we have just created. The `pandas` module is probably the most used and the most versatile method to work with big datasets.
#
# ---

# %%
import csv
import pandas as pd
x = []
y= []
data=[]
for n,i in enumerate(xi):
  for k,j in enumerate(i):
    data.append([j, yi[n][k],n])

with open("milk.csv", 'w', newline='') as myfile:
     wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
     wr.writerow(["PC1", "PC2", "label"])
     wr.writerows(data)

# %%
# Load a dataset into a Pandas Dataframe.
dataset_df = pd.read_csv("milk.csv")

# Display the first 3 examples.
dataset_df.head(10)
# Out:
#          PC1        PC2  label
# 0  23.471052  -9.429722      0
# 1  22.288738  -9.734431      0
# 2  23.006260  -9.219116      0
# 3  21.713207  -8.643313      0
# 4  22.364569 -11.233609      0
# 5  23.809960 -12.160036      0
# 6  24.568117 -11.189903      0
# 7  23.014803 -10.219275      0
# 8  24.373678 -12.047730      0
# 9  23.437150 -10.699658      0

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
import np_utils
from keras.utils import to_categorical
from keras.models import *
from keras.layers import Dense


target = dataset_df["label"]
encoder = LabelEncoder()
encoder.fit(target)
encoded_Y = encoder.transform(target)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = to_categorical(encoded_Y)

# create model
model = Sequential()
model.add(keras.Input(shape=(2,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(9, activation='softmax'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                      │ (None, 8)                   │              24 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 9)                   │              81 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 105 (420.00 B)
#  Trainable params: 105 (420.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
dataset_df.head(4)
ds = dataset_df.values
ds2 = ds[:,0:2].astype(float)

# %%
from sklearn.model_selection import cross_val_score
import tensorflow as tf
estimator = KerasClassifier(build_fn=model, epochs=20, verbose=1)
estimator.fit(ds2,dummy_y)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 3.3591
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0750 - loss: 3.1089
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1730 - loss: 2.7892
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2119 - loss: 2.6149
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2549 - loss: 2.3261
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2850 - loss: 2.1989
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2902 - loss: 2.1098
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3052 - loss: 1.9807
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3309 - loss: 1.8510
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4122 - loss: 1.6671
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4302 - loss: 1.5558
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4452 - loss: 1.4630
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4359 - loss: 1.3543
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5225 - loss: 1.2330
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5344 - loss: 1.2146
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5421 - loss: 1.1332
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5525 - loss: 1.0956
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5852 - loss: 1.0108
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5994 - loss: 0.9714
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6439 - loss: 0.9170
# KerasClassifier(
# 	model=None
# 	build_fn=<Sequential name=sequential_2, built=True>
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=20
# 	class_weight=None
# )

# %%
new_measurement = [2,6]
prob = estimator.predict_proba([new_measurement])
print("\n---------------\n")
print("The new measurement " + str(new_measurement) + " belongs to the 9 categories with probabilities:")
for i,p in enumerate(prob):
  print("- Category %d: probability %.2f%%" % (i,p*100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# ---------------
#
# The new measurement [2, 6] belongs to the 9 categories with probabilities:
# - Category 0: probability 8.49%
# - Category 1: probability 30.80%
# - Category 2: probability 17.86%
# - Category 3: probability 14.01%
# - Category 4: probability 4.76%
# - Category 5: probability 3.78%
# - Category 6: probability 13.22%
# - Category 7: probability 6.95%
# - Category 8: probability 0.12%

# %% [markdown]
# # <font color='red'>**Second application: signal and background discrimination on LHCb data**

# %%
from google.colab import drive
drive.mount('/content/drive')

#ROOT installation and setup
import os
if not os.path.isdir('./root_build'):
  # !unzip /content/drive/MyDrive/root_v6.28.04_Ubuntu_20.04.zip
  # !apt-get install git dpkg-dev cmake g++ gcc binutils libx11-dev libxpm-dev libxft-dev libxext-dev tar gfortran subversion
  # !rm -f root_v6.28.04_Ubuntu_20.04.zip
  # !wget http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
  # !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2_amd64.deb
  # !rm -f libssl1.1_1.1.1f-1ubuntu2_amd64.deb
else:
  print("ROOT is already installed and configured")

import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")
import ctypes
ctypes.cdll.LoadLibrary('/content/root_build/lib//libCore.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libThread.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libTreePlayer.so')

import ROOT
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: root_build/tutorials/math/exampleMultiRoot.C
#   inflating: root_build/tutorials/math/mathcoreGenVector.C
#   inflating: root_build/tutorials/math/principal.C
#   inflating: root_build/tutorials/math/exampleTKDE.C
#   inflating: root_build/tutorials/math/mathcoreCDF.C
#   inflating: root_build/tutorials/math/kdTreeBinning.C
#   inflating: root_build/tutorials/math/Legendre.C
#   inflating: root_build/tutorials/math/mathStudent.C
#   inflating: root_build/tutorials/math/hlquantiles.C
#   inflating: root_build/tutorials/math/mathGammaNormal.C
#   inflating: root_build/tutorials/math/quantiles.C
#   inflating: root_build/tutorials/math/permute.C
#   inflating: root_build/tutorials/math/exampleFunctor.C
#   inflating: root_build/tutorials/math/mathcoreVectorCollection.C
#   inflating: root_build/tutorials/math/binomial.C
#   inflating: root_build/tutorials/math/Rolke.C
#   inflating: root_build/tutorials/math/Bessel.C
#   inflating: root_build/tutorials/math/CrystalBall.C
#   inflating: root_build/tutorials/math/testrandom.C
#   inflating: root_build/tutorials/math/mathcoreVectorIO.C
#   inflating: root_build/tutorials/math/LegendreAssoc.C
#   inflating: root_build/tutorials/math/multidimSampling.C
#   inflating: root_build/tutorials/math/mathcoreVectorFloatIO.C
#   inflating: root_build/tutorials/math/mathcoreSpecFunc.C
#   inflating: root_build/tutorials/math/exampleFunction.py
#   inflating: root_build/tutorials/math/tStudent.C
#   inflating: root_build/tutorials/math/limit.C
#   inflating: root_build/tutorials/math/normalDist.py
#   inflating: root_build/tutorials/math/Legendre.py
#   inflating: root_build/tutorials/math/mathmoreIntegration.C
#   inflating: root_build/tutorials/math/multivarGaus.C
#   inflating: root_build/tutorials/math/chi2test.C
#   inflating: root_build/tutorials/math/vavilov.C
#   inflating: root_build/tutorials/math/tStudent.py
#   inflating: root_build/tutorials/math/quasirandom.C
#   inflating: root_build/tutorials/math/normalDist.C
#   inflating: root_build/tutorials/math/mathBeta.C
#   inflating: root_build/tutorials/math/GammaFun.C
#   inflating: root_build/tutorials/math/mathLaplace.C
#   inflating: root_build/tutorials/math/ChebyshevPol.C
#   inflating: root_build/tutorials/math/mathcoreStatFunc.py
#   inflating: root_build/tutorials/math/BreitWigner.C
#   inflating: root_build/tutorials/math/goftest.C
#   inflating: root_build/tutorials/math/FeldmanCousins.C
#   inflating: root_build/tutorials/math/TSVDUnfoldExample.C
#   inflating: root_build/tutorials/rootlogon.C
#    creating: root_build/tutorials/vecops/
#   inflating: root_build/tutorials/vecops/vo001_AdoptOrOwnMemory.C
#   inflating: root_build/tutorials/vecops/vo004_SortAndSelect.py
#   inflating: root_build/tutorials/vecops/vo003_LogicalOperations.C
#   inflating: root_build/tutorials/vecops/vo005_Combinations.C
#   inflating: root_build/tutorials/vecops/vo001_AdoptOrOwnMemory.py
#   inflating: root_build/tutorials/vecops/vo007_PhysicsHelpers.C
#   inflating: root_build/tutorials/vecops/vo006_IndexManipulation.C
#   inflating: root_build/tutorials/vecops/vo004_SortAndSelect.C
#   inflating: root_build/tutorials/vecops/vo005_Combinations.py
#   inflating: root_build/tutorials/vecops/vo002_VectorCalculations.C
#    creating: root_build/tutorials/histfactory/
#   inflating: root_build/tutorials/histfactory/makeExample.C
#   inflating: root_build/tutorials/histfactory/makeQuickModel.py
#   inflating: root_build/tutorials/histfactory/example.xml
#   inflating: root_build/tutorials/histfactory/example_Expression_channel.xml
#   inflating: root_build/tutorials/histfactory/example_Expression.xml
#   inflating: root_build/tutorials/histfactory/example_DataDriven.xml
#   inflating: root_build/tutorials/histfactory/example_ShapeSys_channel.xml
#   inflating: root_build/tutorials/histfactory/example_channel.xml
#   inflating: root_build/tutorials/histfactory/example_DataDriven_controlRegion.xml
#   inflating: root_build/tutorials/histfactory/example_ShapeSys.xml
#   inflating: root_build/tutorials/histfactory/example_DataDriven_signalRegion.xml
#   inflating: root_build/tutorials/histfactory/hf001_example.C
#   inflating: root_build/tutorials/histfactory/example_ShapeSys2D.xml
#   inflating: root_build/tutorials/histfactory/ModifyInterpolation.C
#   inflating: root_build/tutorials/histfactory/example.py
#   inflating: root_build/tutorials/histfactory/example_ShapeSys2D_channel.xml
#    creating: root_build/tutorials/fitsio/
#   inflating: root_build/tutorials/fitsio/sample5.fits
#   inflating: root_build/tutorials/fitsio/FITS_tutorial5.C
#   inflating: root_build/tutorials/fitsio/FITS_tutorial3.C
#   inflating: root_build/tutorials/fitsio/FITS_tutorial7.C
#   inflating: root_build/tutorials/fitsio/FITS_tutorial6.C
#   inflating: root_build/tutorials/fitsio/sample2.fits
#   inflating: root_build/tutorials/fitsio/rmf.fits
#   inflating: root_build/tutorials/fitsio/sample1.fits
#   inflating: root_build/tutorials/fitsio/FITS_tutorial4.C
#   inflating: root_build/tutorials/fitsio/sample3.fits
#   inflating: root_build/tutorials/fitsio/FITS_tutorial2.C
#   inflating: root_build/tutorials/fitsio/FITS_tutorial8.C
#   inflating: root_build/tutorials/fitsio/sample4.fits
#   inflating: root_build/tutorials/fitsio/FITS_tutorial1.C
#    creating: root_build/tutorials/quadp/
#   inflating: root_build/tutorials/quadp/Quad.h
#   inflating: root_build/tutorials/quadp/portfolio.C
#   inflating: root_build/tutorials/quadp/Quad.cxx
#   inflating: root_build/tutorials/quadp/stock.root
#   inflating: root_build/tutorials/index.md
#    creating: root_build/tutorials/pythia/
#   inflating: root_build/tutorials/pythia/pythia8.C
#   inflating: root_build/tutorials/pythia/pythiaExample.C
#    creating: root_build/tutorials/spectrum/
#   inflating: root_build/tutorials/spectrum/TSpectrum.root
#   inflating: root_build/tutorials/spectrum/Deconvolution2_2.C
#   inflating: root_build/tutorials/spectrum/FitAwmi.C
#   inflating: root_build/tutorials/spectrum/Deconvolution2_1.C
#   inflating: root_build/tutorials/spectrum/spectrumpainter.C
#   inflating: root_build/tutorials/spectrum/Background_width.C
#   inflating: root_build/tutorials/spectrum/Smooth.C
#   inflating: root_build/tutorials/spectrum/Src5.C
#   inflating: root_build/tutorials/spectrum/SearchHR3.C
#   inflating: root_build/tutorials/spectrum/Background_smooth.C
#   inflating: root_build/tutorials/spectrum/Background_gamma64.C
#   inflating: root_build/tutorials/spectrum/Background_order.C
#   inflating: root_build/tutorials/spectrum/Background_synt256.C
#   inflating: root_build/tutorials/spectrum/DeconvolutionRL_wide_boost.C
#   inflating: root_build/tutorials/spectrum/peaks.C
#   inflating: root_build/tutorials/spectrum/Smoothing.C
#   inflating: root_build/tutorials/spectrum/peaks2.C
#   inflating: root_build/tutorials/spectrum/Src4.C
#   inflating: root_build/tutorials/spectrum/Background_compton.C
#   inflating: root_build/tutorials/spectrum/Background_incr.C
#   inflating: root_build/tutorials/spectrum/Src3.C
#   inflating: root_build/tutorials/spectrum/Background_gamma256.C
#   inflating: root_build/tutorials/spectrum/Deconvolution2_HR.C
#   inflating: root_build/tutorials/spectrum/Src2.C
#   inflating: root_build/tutorials/spectrum/Deconvolution_wide.C
#   inflating: root_build/tutorials/spectrum/Deconvolution.C
#   inflating: root_build/tutorials/spectrum/Background_decr.C
#   inflating: root_build/tutorials/spectrum/Deconvolution_wide_boost.C
#   inflating: root_build/tutorials/spectrum/Background_width2.C
#   inflating: root_build/tutorials/spectrum/DeconvolutionRL_wide.C
#   inflating: root_build/tutorials/spectrum/Src.C
#   inflating: root_build/tutorials/spectrum/SearchHR1.C
#   inflating: root_build/tutorials/spectrum/TSpectrum2.root
#    creating: root_build/tutorials/mc/
#   inflating: root_build/tutorials/mc/mass_width_2008.mc.txt
#   inflating: root_build/tutorials/mc/CompareMasses.C
#    creating: root_build/tutorials/eve7/
#   inflating: root_build/tutorials/eve7/lego.C
#   inflating: root_build/tutorials/eve7/tracks.C
#   inflating: root_build/tutorials/eve7/csgdemo.C
#   inflating: root_build/tutorials/eve7/geom_cms.C
#   inflating: root_build/tutorials/eve7/event_demo.C
#   inflating: root_build/tutorials/eve7/projection_prescale.C
#   inflating: root_build/tutorials/eve7/show_extract.C
#   inflating: root_build/tutorials/eve7/collection_proxies.C
#   inflating: root_build/tutorials/eve7/compound.C
#   inflating: root_build/tutorials/eve7/points.C
#   inflating: root_build/tutorials/eve7/calorimeters.C
#   inflating: root_build/tutorials/eve7/boxset.C
#   inflating: root_build/tutorials/eve7/error_ellipse.C
#   inflating: root_build/tutorials/eve7/jets.C
#   inflating: root_build/tutorials/eve7/lineset.C
#   inflating: root_build/tutorials/eve7/box.C
#   inflating: root_build/tutorials/CMakeLists.txt
#    creating: root_build/tutorials/http/
#   inflating: root_build/tutorials/http/ws.C
#   inflating: root_build/tutorials/http/httpaccess.C
#   inflating: root_build/tutorials/http/auth.txt
#   inflating: root_build/tutorials/http/ws.htm
#   inflating: root_build/tutorials/http/httpgeom.C
#   inflating: root_build/tutorials/http/httpserver.C
#   inflating: root_build/tutorials/http/httptextlog.js
#   inflating: root_build/tutorials/http/custom.htm
#   inflating: root_build/tutorials/http/custom.C
#   inflating: root_build/tutorials/http/httpcontrol.C
#   inflating: root_build/tutorials/http/httptextlog.C
#   inflating: root_build/tutorials/http/histfitserver.C
#    creating: root_build/tutorials/graphs/
#   inflating: root_build/tutorials/graphs/gtime.C
#   inflating: root_build/tutorials/graphs/multigraphpalettecolor.C
#   inflating: root_build/tutorials/graphs/seism.C
#   inflating: root_build/tutorials/graphs/graphpolar.C
#   inflating: root_build/tutorials/graphs/graphtext.C
#   inflating: root_build/tutorials/graphs/approx.C
#   inflating: root_build/tutorials/graphs/timeonaxis2.C
#   inflating: root_build/tutorials/graphs/gerrors.C
#   inflating: root_build/tutorials/graphs/timeSeriesFromCSV_TDF.C
#   inflating: root_build/tutorials/graphs/graphApply.C
#   inflating: root_build/tutorials/graphs/zones.C
#   inflating: root_build/tutorials/graphs/bent.C
#   inflating: root_build/tutorials/graphs/exclusiongraph2.C
#   inflating: root_build/tutorials/graphs/bent.py
#   inflating: root_build/tutorials/graphs/multigraph.C
#   inflating: root_build/tutorials/graphs/zdemo.C
#   inflating: root_build/tutorials/graphs/motorcycle.dat
#   inflating: root_build/tutorials/graphs/splines_test.C
#   inflating: root_build/tutorials/graphs/timeonaxis.C
#   inflating: root_build/tutorials/graphs/timeonaxis3.C
#   inflating: root_build/tutorials/graphs/hlGraph2.C
#   inflating: root_build/tutorials/graphs/SWAN2017.dat
#   inflating: root_build/tutorials/graphs/gtime2.C
#   inflating: root_build/tutorials/graphs/timeSeriesFromCSV.C
#   inflating: root_build/tutorials/graphs/graphpolar2.C
#   inflating: root_build/tutorials/graphs/waves.C
#   inflating: root_build/tutorials/graphs/motorcycle.C
#   inflating: root_build/tutorials/graphs/zones.py
#   inflating: root_build/tutorials/graphs/graph2derrorsfit.C
#   inflating: root_build/tutorials/graphs/graph.C
#   inflating: root_build/tutorials/graphs/gerrors2.C
#   inflating: root_build/tutorials/graphs/graphstruct.C
#   inflating: root_build/tutorials/graphs/timeSeriesFromCSV.py
#   inflating: root_build/tutorials/graphs/graphpalettecolor.C
#   inflating: root_build/tutorials/graphs/exclusiongraph.C
#   inflating: root_build/tutorials/graphs/gmultierrors.C
#   inflating: root_build/tutorials/graphs/annotation3d.C
#   inflating: root_build/tutorials/graphs/graphShade.C
#   inflating: root_build/tutorials/graphs/surfaces.C
#   inflating: root_build/tutorials/graphs/hlGraph1.C
#   inflating: root_build/tutorials/graphs/multipalette.C
#   inflating: root_build/tutorials/graphs/labels2.C
#   inflating: root_build/tutorials/graphs/graphpolar3.C
#   inflating: root_build/tutorials/graphs/labels1.C
#    creating: root_build/tutorials/r/
#   inflating: root_build/tutorials/r/GlobalMinimization.C
#   inflating: root_build/tutorials/r/DataFrame.C
#   inflating: root_build/tutorials/r/Interpolation.C
#   inflating: root_build/tutorials/r/SimpleFitting.C
#   inflating: root_build/tutorials/r/example.C
#   inflating: root_build/tutorials/r/Function.C
#   inflating: root_build/tutorials/r/Functor.C
#   inflating: root_build/tutorials/r/Integration.C
#   inflating: root_build/tutorials/r/Minimization.C
#   inflating: root_build/tutorials/rootlogoff.C
#    creating: root_build/tutorials/foam/
#   inflating: root_build/tutorials/foam/index.md
#   inflating: root_build/tutorials/foam/foam_demo.C
#   inflating: root_build/tutorials/foam/foam_demopers.C
#   inflating: root_build/tutorials/foam/foam_kanwa.C
#    creating: root_build/tutorials/image/
#   inflating: root_build/tutorials/image/fore.xpm
#   inflating: root_build/tutorials/image/galaxy_image.C
#   inflating: root_build/tutorials/image/img2pad.C
#   inflating: root_build/tutorials/image/image2hist.C
#   inflating: root_build/tutorials/image/mditestbg.xpm
#   inflating: root_build/tutorials/image/pad2png.C
#   inflating: root_build/tutorials/image/imgconv.C
#   inflating: root_build/tutorials/image/rose512.jpg
#   inflating: root_build/tutorials/image/hsumanim.C
#   inflating: root_build/tutorials/image/hist2image.C
#   inflating: root_build/tutorials/image/rose_image.C
#   inflating: root_build/tutorials/image/trans_graph.C
#    creating: root_build/tutorials/geom/
#   inflating: root_build/tutorials/geom/shapes.C
#   inflating: root_build/tutorials/geom/lego.C
#   inflating: root_build/tutorials/geom/mp3player.C
#   inflating: root_build/tutorials/geom/csgdemo.C
#   inflating: root_build/tutorials/geom/building.C
#    creating: root_build/tutorials/geom/gdml/
#   inflating: root_build/tutorials/geom/gdml/testoptical.C
#   inflating: root_build/tutorials/geom/gdml/opticalsurfaces.gdml
#   inflating: root_build/tutorials/geom/geomD0.C
#   inflating: root_build/tutorials/geom/geomBrahms.C
#   inflating: root_build/tutorials/geom/iterplugin.cxx
#   inflating: root_build/tutorials/geom/runplugin.C
#   inflating: root_build/tutorials/geom/webhelp.html
#   inflating: root_build/tutorials/geom/webdemo.C
#   inflating: root_build/tutorials/geom/geomAlice.C
#   inflating: root_build/tutorials/geom/xtruSamples.C
#   inflating: root_build/tutorials/geom/geodemo.C
#   inflating: root_build/tutorials/geom/na49.C
#   inflating: root_build/tutorials/geom/xtruDraw.C
#   inflating: root_build/tutorials/geom/south_gate.C
#   inflating: root_build/tutorials/geom/teddy.obj
#   inflating: root_build/tutorials/geom/assembly.C
#   inflating: root_build/tutorials/geom/na49geomfile.C
#   inflating: root_build/tutorials/geom/RadioNuclides.C
#   inflating: root_build/tutorials/geom/geometry.C
#   inflating: root_build/tutorials/geom/tank.C
#   inflating: root_build/tutorials/geom/cheongwadae.C
#   inflating: root_build/tutorials/geom/parallel_world.C
#   inflating: root_build/tutorials/geom/web_cms.cxx
#   inflating: root_build/tutorials/geom/visualizeWavefrontObj.C
#   inflating: root_build/tutorials/geom/shapesAnim.C
#   inflating: root_build/tutorials/geom/geomAtlas.C
#   inflating: root_build/tutorials/geom/robot.C
#   inflating: root_build/tutorials/geom/webdemo.html
#   inflating: root_build/tutorials/geom/station2.C
#   inflating: root_build/tutorials/geom/na49view.C
#   inflating: root_build/tutorials/geom/geomAlice_itsv.C
#   inflating: root_build/tutorials/geom/rootgeom.C
#   inflating: root_build/tutorials/geom/station1.C
#    creating: root_build/tutorials/webgui/
#    creating: root_build/tutorials/webgui/webwindow/
#   inflating: root_build/tutorials/webgui/webwindow/server.cxx
#   inflating: root_build/tutorials/webgui/webwindow/client.html
#    creating: root_build/tutorials/webgui/ping/
#   inflating: root_build/tutorials/webgui/ping/ping.html
#   inflating: root_build/tutorials/webgui/ping/ping.cxx
#   inflating: root_build/tutorials/webgui/ping/Readme.md
#    creating: root_build/tutorials/webgui/qt5web/
#   inflating: root_build/tutorials/webgui/qt5web/TCanvasWidget.h
#   inflating: root_build/tutorials/webgui/qt5web/ExampleWidget.cpp
#   inflating: root_build/tutorials/webgui/qt5web/CMakeLists.txt
#   inflating: root_build/tutorials/webgui/qt5web/TCanvasWidget.cpp
#   inflating: root_build/tutorials/webgui/qt5web/RGeomViewerWidget.h
#   inflating: root_build/tutorials/webgui/qt5web/RGeomViewerWidget.cpp
#   inflating: root_build/tutorials/webgui/qt5web/RCanvasWidget.cpp
#   inflating: root_build/tutorials/webgui/qt5web/ExampleWidget.ui
#   inflating: root_build/tutorials/webgui/qt5web/Readme.md
#   inflating: root_build/tutorials/webgui/qt5web/ExampleWidget.h
#   inflating: root_build/tutorials/webgui/qt5web/RCanvasWidget.h
#   inflating: root_build/tutorials/webgui/qt5web/ExampleMain.cpp
#    creating: root_build/tutorials/webgui/panel/
#    creating: root_build/tutorials/webgui/panel/controller/
#   inflating: root_build/tutorials/webgui/panel/controller/TestPanel.controller.js
#   inflating: root_build/tutorials/webgui/panel/server.cxx
#    creating: root_build/tutorials/webgui/panel/view/
#   inflating: root_build/tutorials/webgui/panel/view/TestPanel.view.xml
#   inflating: root_build/tutorials/webgui/panel/Readme.md
#    creating: root_build/tutorials/xml/
#   inflating: root_build/tutorials/xml/SAXHandler.C
#   inflating: root_build/tutorials/xml/xmlreadfile.C
#   inflating: root_build/tutorials/xml/xmlnewfile.C
#   inflating: root_build/tutorials/xml/saxexample.xml
#   inflating: root_build/tutorials/xml/DOMParsePerson.C
#   inflating: root_build/tutorials/xml/person.dtd
#   inflating: root_build/tutorials/xml/DOMRecursive.C
#   inflating: root_build/tutorials/xml/person.xml
#   inflating: root_build/tutorials/xml/xmlmodifyfile.C
#    creating: root_build/tutorials/html/
#   inflating: root_build/tutorials/html/MakeTutorials.C
#    creating: root_build/tutorials/pyroot/
#   inflating: root_build/tutorials/pyroot/pyroot005_tfile_context_manager.py
#   inflating: root_build/tutorials/pyroot/pyroot002_pythonizationDecorator.py
#   inflating: root_build/tutorials/pyroot/na49visible.py
#   inflating: root_build/tutorials/pyroot/pyroot006_tcontext_context_manager.py
#   inflating: root_build/tutorials/pyroot/na49geomfile.py
#   inflating: root_build/tutorials/pyroot/example_data.dat
#   inflating: root_build/tutorials/pyroot/pyroot004_NumbaDeclare.py
#   inflating: root_build/tutorials/pyroot/shapes.py
#   inflating: root_build/tutorials/pyroot/fillrandom.py
#   inflating: root_build/tutorials/pyroot/pyroot003_prettyPrinting.py
#   inflating: root_build/tutorials/pyroot/gui_ex.py
#   inflating: root_build/tutorials/pyroot/ntuple1.py
#   inflating: root_build/tutorials/pyroot/h1ReadAndDraw.py
#   inflating: root_build/tutorials/pyroot/formula1.py
#   inflating: root_build/tutorials/pyroot/DynamicSlice.py
#   inflating: root_build/tutorials/pyroot/mrt.py
#   inflating: root_build/tutorials/pyroot/demo.py
#   inflating: root_build/tutorials/pyroot/tornado.py
#   inflating: root_build/tutorials/pyroot/graph.py
#   inflating: root_build/tutorials/pyroot/zdemo.py
#   inflating: root_build/tutorials/pyroot/gerrors.py
#   inflating: root_build/tutorials/pyroot/pyroot001_arrayInterface.py
#   inflating: root_build/tutorials/pyroot/geometry.py
#   inflating: root_build/tutorials/pyroot/staff.py
#   inflating: root_build/tutorials/pyroot/numberEntry.py
#   inflating: root_build/tutorials/pyroot/ratioplot.py
#   inflating: root_build/tutorials/pyroot/na49view.py
#   inflating: root_build/tutorials/pyroot/hsimple.py
#   inflating: root_build/tutorials/pyroot/parse_CSV_file_with_TTree_ReadStream.py
#   inflating: root_build/tutorials/pyroot/fit1.py
#   inflating: root_build/tutorials/pyroot/fit1_py.py
#   inflating: root_build/tutorials/pyroot/hsum.py
#   inflating: root_build/tutorials/pyroot/surfaces.py
#   inflating: root_build/tutorials/pyroot/demoshelp.py
#   inflating: root_build/tutorials/pyroot/aptuple.txt
#    creating: root_build/tutorials/graphics/
#   inflating: root_build/tutorials/graphics/feynman.C
#   inflating: root_build/tutorials/graphics/gtime.C
#   inflating: root_build/tutorials/graphics/diamond.C
#   inflating: root_build/tutorials/graphics/gaxis3.C
#   inflating: root_build/tutorials/graphics/quarks.C
#   inflating: root_build/tutorials/graphics/canvas2.C
#   inflating: root_build/tutorials/graphics/greyscale.C
#   inflating: root_build/tutorials/graphics/tmathtext2.C
#   inflating: root_build/tutorials/graphics/anim.C
#   inflating: root_build/tutorials/graphics/graph_edit_playback.C
#   inflating: root_build/tutorials/graphics/polytest1.C
#   inflating: root_build/tutorials/graphics/earth.C
#   inflating: root_build/tutorials/graphics/compile.C
#   inflating: root_build/tutorials/graphics/archi.C
#   inflating: root_build/tutorials/graphics/tornado.C
#   inflating: root_build/tutorials/graphics/psview.C
#   inflating: root_build/tutorials/graphics/schroedinger_hydrogen.C
#   inflating: root_build/tutorials/graphics/piechart.C
#   inflating: root_build/tutorials/graphics/transparency.C
#   inflating: root_build/tutorials/graphics/tmathtext.C
#   inflating: root_build/tutorials/graphics/framework.C
#   inflating: root_build/tutorials/graphics/analyze.C
#   inflating: root_build/tutorials/graphics/mass_spectrum.C
#   inflating: root_build/tutorials/graphics/crown.C
#   inflating: root_build/tutorials/graphics/triangles.C
#   inflating: root_build/tutorials/graphics/earth.dat
#   inflating: root_build/tutorials/graphics/first.C
#   inflating: root_build/tutorials/graphics/gaxis2.C
#   inflating: root_build/tutorials/graphics/palettes.C
#   inflating: root_build/tutorials/graphics/AtlasExample.C
#   inflating: root_build/tutorials/graphics/latex2.C
#   inflating: root_build/tutorials/graphics/formula1.C
#   inflating: root_build/tutorials/graphics/latex3.C
#   inflating: root_build/tutorials/graphics/event.C
#   inflating: root_build/tutorials/graphics/latex4.C
#   inflating: root_build/tutorials/graphics/polytest2.C
#   inflating: root_build/tutorials/graphics/mandelbrot.C
#   inflating: root_build/tutorials/graphics/gaxis.C
#   inflating: root_build/tutorials/graphics/pavetext.C
#   inflating: root_build/tutorials/graphics/eval.C
#   inflating: root_build/tutorials/graphics/markerwarning.C
#   inflating: root_build/tutorials/graphics/ellipse.C
#   inflating: root_build/tutorials/graphics/arrows.C
#   inflating: root_build/tutorials/graphics/perceptualcolormap.C
#   inflating: root_build/tutorials/graphics/pstable.C
#   inflating: root_build/tutorials/graphics/latex5.C
#   inflating: root_build/tutorials/graphics/canvas.C
#   inflating: root_build/tutorials/graphics/basic3d.C
#   inflating: root_build/tutorials/graphics/latex.C
#    creating: root_build/tutorials/fit/
#   inflating: root_build/tutorials/fit/vectorizedFit.C
#   inflating: root_build/tutorials/fit/multifit.C
#   inflating: root_build/tutorials/fit/exampleFit3D.C
#   inflating: root_build/tutorials/fit/combinedFit.py
#   inflating: root_build/tutorials/fit/fitLinearRobust.C
#   inflating: root_build/tutorials/fit/minuit2GausFit.C
#   inflating: root_build/tutorials/fit/fitMultiGraph.C
#   inflating: root_build/tutorials/fit/fitcont.C
#   inflating: root_build/tutorials/fit/fitNormSum.C
#   inflating: root_build/tutorials/fit/fitConvolution.C
#   inflating: root_build/tutorials/fit/fitpanel_playback.C
#   inflating: root_build/tutorials/fit/fit2a.C
#   inflating: root_build/tutorials/fit/fit2d.C
#   inflating: root_build/tutorials/fit/myfit.C
#   inflating: root_build/tutorials/fit/ErrorIntegral.C
#   inflating: root_build/tutorials/fit/minuit2FitBench2D.C
#   inflating: root_build/tutorials/fit/fitslicesy.C
#   inflating: root_build/tutorials/fit/NumericalMinimization.C
#   inflating: root_build/tutorials/fit/fitLinear.C
#   inflating: root_build/tutorials/fit/TwoHistoFit2D.C
#   inflating: root_build/tutorials/fit/fitConvolution.py
#   inflating: root_build/tutorials/fit/FitHistoInFile.C
#   inflating: root_build/tutorials/fit/qa2.C
#   inflating: root_build/tutorials/fit/fitExclude.C
#   inflating: root_build/tutorials/fit/multidimfit.C
#   inflating: root_build/tutorials/fit/fitNormSum.py
#   inflating: root_build/tutorials/fit/minuit2FitBench.C
#   inflating: root_build/tutorials/fit/multifit.py
#   inflating: root_build/tutorials/fit/fitEllipseTGraphDLSF.cxx
#   inflating: root_build/tutorials/fit/fithist.C
#   inflating: root_build/tutorials/fit/graph2dfit.C
#   inflating: root_build/tutorials/fit/fit2.C
#   inflating: root_build/tutorials/fit/TestBinomial.C
#   inflating: root_build/tutorials/fit/fit2dHist.C
#   inflating: root_build/tutorials/fit/fit1.C
#   inflating: root_build/tutorials/fit/ConfidenceIntervals.C
#   inflating: root_build/tutorials/fit/fitEllipseTGraphRMM.cxx
#   inflating: root_build/tutorials/fit/line3Dfit.C
#   inflating: root_build/tutorials/fit/fitLinear2.C
#   inflating: root_build/tutorials/fit/combinedFit.C
#   inflating: root_build/tutorials/fit/Ifit.C
#   inflating: root_build/tutorials/fit/langaus.C
#   inflating: root_build/tutorials/fit/FittingDemo.C
#   inflating: root_build/tutorials/fit/fit1_C.txt
#   inflating: root_build/tutorials/fit/fitCircle.C
#    creating: root_build/tutorials/cocoa/
#   inflating: root_build/tutorials/cocoa/index.md
#   inflating: root_build/tutorials/cocoa/grad.C
#   inflating: root_build/tutorials/cocoa/transp_text.C
#   inflating: root_build/tutorials/cocoa/transparentpad.C
#   inflating: root_build/tutorials/cocoa/transp.C
#   inflating: root_build/tutorials/cocoa/flower.C
#   inflating: root_build/tutorials/cocoa/radialgradients.C
#   inflating: root_build/tutorials/cocoa/gradients.C
#   inflating: root_build/tutorials/cocoa/customcolor.h
#   inflating: root_build/tutorials/cocoa/grad2.C
#   inflating: root_build/tutorials/cocoa/parallelcoordtrans.C
#    creating: root_build/tutorials/io/
#   inflating: root_build/tutorials/io/double32.C
#   inflating: root_build/tutorials/io/testMergeCont.C
#   inflating: root_build/tutorials/io/loopdir.C
#   inflating: root_build/tutorials/io/importCode.C
#   inflating: root_build/tutorials/io/file.C
#   inflating: root_build/tutorials/io/testTMPIFile.C
#   inflating: root_build/tutorials/io/readCode.C
#   inflating: root_build/tutorials/io/copyFiles.C
#   inflating: root_build/tutorials/io/dirs.C
#   inflating: root_build/tutorials/io/fildir.C
#   inflating: root_build/tutorials/io/hadd.C
#   inflating: root_build/tutorials/io/loopdir11.C
#   inflating: root_build/tutorials/io/float16.C
#   inflating: root_build/tutorials/io/mergeSelective.C
#   inflating: root_build/tutorials/gallery.root
#    creating: root_build/tutorials/legacy/
#    creating: root_build/tutorials/legacy/mlp/
#   inflating: root_build/tutorials/legacy/mlp/mlpHiggs.C
#   inflating: root_build/tutorials/legacy/mlp/index.md
#   inflating: root_build/tutorials/legacy/mlp/mlpRegression.C
#   inflating: root_build/tutorials/legacy/mlp/mlpHiggs.root
#   inflating: root_build/tutorials/legacy/tasks.C
#    creating: root_build/tutorials/legacy/regexp/
#   inflating: root_build/tutorials/legacy/regexp/regexp_pme.C
#   inflating: root_build/tutorials/legacy/regexp/index.md
#   inflating: root_build/tutorials/legacy/regexp/regexp.C
#   inflating: root_build/tutorials/legacy/index.md
#   inflating: root_build/tutorials/legacy/rootenv.C
#    creating: root_build/tutorials/legacy/thread/
#   inflating: root_build/tutorials/legacy/thread/index.md
#   inflating: root_build/tutorials/legacy/thread/threadsh2.C
#   inflating: root_build/tutorials/legacy/thread/threadPool.C
#   inflating: root_build/tutorials/legacy/thread/threadsh1.C
#   inflating: root_build/tutorials/legacy/thread/stressThreadPool.C
#   inflating: root_build/tutorials/legacy/thread/threads.C
#   inflating: root_build/tutorials/legacy/benchmarks.C
#   inflating: root_build/tutorials/legacy/MyTasks.cxx
#    creating: root_build/tutorials/legacy/pyroot/
#   inflating: root_build/tutorials/legacy/pyroot/benchmarks.py
#   inflating: root_build/tutorials/legacy/pyroot/test.py
#   inflating: root_build/tutorials/legacy/pyroot/file.py
#   inflating: root_build/tutorials/legacy/pyroot/first.py
#   inflating: root_build/tutorials/legacy/pyroot/index.md
#   inflating: root_build/tutorials/legacy/pyroot/fildir.py
#   inflating: root_build/tutorials/legacy/pyroot/framework.py
#   inflating: root_build/tutorials/legacy/pyroot/tree.py
#   inflating: root_build/tutorials/legacy/pyroot/rootmarks.py
#   inflating: root_build/tutorials/legacy/htmlex.C
#   inflating: root_build/tutorials/legacy/rootalias.C
#   inflating: root_build/tutorials/legacy/geant3tasks.C
#   inflating: root_build/tutorials/legacy/rootmarks.C
#    creating: root_build/tutorials/legacy/cont/
#   inflating: root_build/tutorials/legacy/cont/index.md
#   inflating: root_build/tutorials/legacy/cont/TListAndSTL.C
#    creating: root_build/tutorials/eve/
#   inflating: root_build/tutorials/eve/projection.C
#   inflating: root_build/tutorials/eve/csgdemo.C
#   inflating: root_build/tutorials/eve/track.C
#   inflating: root_build/tutorials/eve/geom_alice_tpc.C
#   inflating: root_build/tutorials/eve/geom_cms_playback.C
#   inflating: root_build/tutorials/eve/camera_restore.C
#   inflating: root_build/tutorials/eve/geom_alice_its.C
#   inflating: root_build/tutorials/eve/view3ds.C
#   inflating: root_build/tutorials/eve/geom_cms.C
#   inflating: root_build/tutorials/eve/projection_prescale.C
#   inflating: root_build/tutorials/eve/show_extract.C
#   inflating: root_build/tutorials/eve/text.C
#   inflating: root_build/tutorials/eve/nasashuttle.3ds
#   inflating: root_build/tutorials/eve/geom_atlas.C
#   inflating: root_build/tutorials/eve/geom_lhcb.C
#   inflating: root_build/tutorials/eve/annotation.C
#   inflating: root_build/tutorials/eve/boxset_cones.C
#   inflating: root_build/tutorials/eve/alice_esd_html_summary.C
#   inflating: root_build/tutorials/eve/compound.C
#   inflating: root_build/tutorials/eve/geom_atlas_playback.C
#   inflating: root_build/tutorials/eve/MultiView.C
#   inflating: root_build/tutorials/eve/pointset.C
#   inflating: root_build/tutorials/eve/glplot_geom.C
#   inflating: root_build/tutorials/eve/window_manager.C
#   inflating: root_build/tutorials/eve/paramlist.C
#   inflating: root_build/tutorials/eve/glplot.C
#   inflating: root_build/tutorials/eve/geom_alias.C
#   inflating: root_build/tutorials/eve/triangleset.C
#   inflating: root_build/tutorials/eve/arrow_standalone.C
#   inflating: root_build/tutorials/eve/hierarchical_scene.C
#   inflating: root_build/tutorials/eve/calorimeters.C
#   inflating: root_build/tutorials/eve/arrow.C
#   inflating: root_build/tutorials/eve/quadset.C
#   inflating: root_build/tutorials/eve/boxset.C
#   inflating: root_build/tutorials/eve/geom_default.C
#   inflating: root_build/tutorials/eve/alice_esd_split.C
#   inflating: root_build/tutorials/eve/lineset.py
#   inflating: root_build/tutorials/eve/assembly.C
#   inflating: root_build/tutorials/eve/jetcone.C
#   inflating: root_build/tutorials/eve/overlay_palette.C
#   inflating: root_build/tutorials/eve/selection_sigs.C
#   inflating: root_build/tutorials/eve/alice_vsd.C
#   inflating: root_build/tutorials/eve/calo_detail.C
#  extracting: root_build/tutorials/eve/swap.png
#   inflating: root_build/tutorials/eve/run_alice_esd_split.C
#   inflating: root_build/tutorials/eve/geom_cms_stereo.C
#   inflating: root_build/tutorials/eve/lineset.C
#   inflating: root_build/tutorials/eve/SplitGLView.C
#   inflating: root_build/tutorials/eve/box.C
#   inflating: root_build/tutorials/eve/broken_torus.tring
#   inflating: root_build/tutorials/eve/run_alice_esd.C
#   inflating: root_build/tutorials/eve/pythia_display.C
#  extracting: root_build/tutorials/eve/Default.png
#   inflating: root_build/tutorials/eve/alice_esd.C
#   inflating: root_build/tutorials/eve/pack.C
#   inflating: root_build/tutorials/eve/histobrowser.C
#    creating: root_build/tutorials/gl/
#   inflating: root_build/tutorials/gl/glViewerLOD.C
#   inflating: root_build/tutorials/gl/glparametric.C
#   inflating: root_build/tutorials/gl/gltf3.C
#   inflating: root_build/tutorials/gl/glh3c.C
#   inflating: root_build/tutorials/gl/glvox2.C
#   inflating: root_build/tutorials/gl/customcolorgl.h
#   inflating: root_build/tutorials/gl/gviz3d.C
#   inflating: root_build/tutorials/gl/grad.C
#   inflating: root_build/tutorials/gl/viewer3DMaster.C
#   inflating: root_build/tutorials/gl/transp_text.C
#   inflating: root_build/tutorials/gl/glrose.C
#   inflating: root_build/tutorials/gl/nucleus.C
#   inflating: root_build/tutorials/gl/viewer3DLocal.C
#   inflating: root_build/tutorials/gl/glViewerExercise.C
#   inflating: root_build/tutorials/gl/transparentpad.C
#   inflating: root_build/tutorials/gl/transp.C
#   inflating: root_build/tutorials/gl/glparametrics2.C
#   inflating: root_build/tutorials/gl/radialgradients.C
#   inflating: root_build/tutorials/gl/gradients.C
#   inflating: root_build/tutorials/gl/glsurfaces.C
#   inflating: root_build/tutorials/gl/gldemos.C
#   inflating: root_build/tutorials/gl/grad2.C
#   inflating: root_build/tutorials/gl/parallelcoordtrans.C
#   inflating: root_build/tutorials/gl/glbox.C
#   inflating: root_build/tutorials/gl/glvox1.C
#    creating: root_build/tutorials/net/
#   inflating: root_build/tutorials/net/hprod.C
#   inflating: root_build/tutorials/net/hserv2.C
#   inflating: root_build/tutorials/net/TestAuth.C
#   inflating: root_build/tutorials/net/authserv.C
#   inflating: root_build/tutorials/net/pclient.C
#   inflating: root_build/tutorials/net/spy.C
#   inflating: root_build/tutorials/net/parallelMergeTest.sh
#   inflating: root_build/tutorials/net/TUriTest.C
#   inflating: root_build/tutorials/net/udpserver.c
#   inflating: root_build/tutorials/net/treeClient.C
#   inflating: root_build/tutorials/net/hclient.C
#   inflating: root_build/tutorials/net/parallelMergeServer.C
#   inflating: root_build/tutorials/net/parallelMergeClient.C
#   inflating: root_build/tutorials/net/hcons.C
#   inflating: root_build/tutorials/net/fastMergeServer.C
#   inflating: root_build/tutorials/net/parallelMergeTest.C
#   inflating: root_build/tutorials/net/testTUDPSocket.C
#   inflating: root_build/tutorials/net/authclient.C
#   inflating: root_build/tutorials/net/pserv.C
#   inflating: root_build/tutorials/net/spyserv.C
#   inflating: root_build/tutorials/net/hserv.C
#    creating: root_build/tutorials/tree/
#   inflating: root_build/tutorials/tree/parallelcoord.C
#   inflating: root_build/tutorials/tree/tree3.C
#   inflating: root_build/tutorials/tree/htest.C
#   inflating: root_build/tutorials/tree/basic2.C
#   inflating: root_build/tutorials/tree/ntuple1.C
#   inflating: root_build/tutorials/tree/tree1.C
#   inflating: root_build/tutorials/tree/cernstaff.dat
#   inflating: root_build/tutorials/tree/simpleAnalysis.txt
#   inflating: root_build/tutorials/tree/basic.C
#   inflating: root_build/tutorials/tree/treefriend.C
#   inflating: root_build/tutorials/tree/JetEvent.cxx
#   inflating: root_build/tutorials/tree/printSizes.C
#   inflating: root_build/tutorials/tree/tv3.C
#   inflating: root_build/tutorials/tree/clonesA_Event.cxx
#   inflating: root_build/tutorials/tree/drawsparse.C
#   inflating: root_build/tutorials/tree/tree2.C
#   inflating: root_build/tutorials/tree/run_h1analysis.C
#  extracting: root_build/tutorials/tree/h1analysisProxyCut.C
#   inflating: root_build/tutorials/tree/tcl.C
#   inflating: root_build/tutorials/tree/clonesA_Event.h
#   inflating: root_build/tutorials/tree/temperature_Prague.dat
#   inflating: root_build/tutorials/tree/clonesA_Event.C
#   inflating: root_build/tutorials/tree/h1analysisProxy.h
#   inflating: root_build/tutorials/tree/tree4.C
#   inflating: root_build/tutorials/tree/hsimpleProxyDriver.C
#   inflating: root_build/tutorials/tree/h1analysis.h
#   inflating: root_build/tutorials/tree/hvector.C
#   inflating: root_build/tutorials/tree/tree0.C
#   inflating: root_build/tutorials/tree/cernstaff.C
#   inflating: root_build/tutorials/tree/staff.C
#   inflating: root_build/tutorials/tree/spider.C
#   inflating: root_build/tutorials/tree/jets.C
#   inflating: root_build/tutorials/tree/h1analysis.C
#   inflating: root_build/tutorials/tree/basic.dat
#   inflating: root_build/tutorials/tree/temperature.C
#   inflating: root_build/tutorials/tree/copytree.C
#   inflating: root_build/tutorials/tree/circular.C
#   inflating: root_build/tutorials/tree/copytree3.C
#   inflating: root_build/tutorials/tree/treegetval.C
#   inflating: root_build/tutorials/tree/JetEvent.h
#   inflating: root_build/tutorials/tree/cernbuild.C
#   inflating: root_build/tutorials/tree/parallelcoordtrans.C
#   inflating: root_build/tutorials/tree/h1analysisProxy.C
#   inflating: root_build/tutorials/tree/h1chain.C
#   inflating: root_build/tutorials/tree/tree.C
#   inflating: root_build/tutorials/tree/hsimpleProxy.C
#   inflating: root_build/tutorials/tree/tvdemo.C
#   inflating: root_build/tutorials/tree/h1analysisTreeReader.C
#   inflating: root_build/tutorials/tree/hsimpleReader.C
#   inflating: root_build/tutorials/tree/h1analysisTreeReader.h
#   inflating: root_build/tutorials/tree/bill.C
#   inflating: root_build/tutorials/tree/tree2a.C
#   inflating: root_build/tutorials/tree/copytree2.C
#    creating: root_build/tutorials/multicore/
#   inflating: root_build/tutorials/multicore/mp102_readNtuplesFillHistosAndFit.C
#   inflating: root_build/tutorials/multicore/mt101_fillNtuples.C
#   inflating: root_build/tutorials/multicore/mp201_parallelHistoFill.C
#   inflating: root_build/tutorials/multicore/imt001_parBranchProcessing.C
#   inflating: root_build/tutorials/multicore/mt201_parallelHistoFill.C
#   inflating: root_build/tutorials/multicore/mt301_TTaskGroupSimple.C
#   inflating: root_build/tutorials/multicore/imt101_parTreeProcessing.C
#   inflating: root_build/tutorials/multicore/mt001_fillHistos.C
#   inflating: root_build/tutorials/multicore/mt102_readNtuplesFillHistosAndFit.C
#   inflating: root_build/tutorials/multicore/mp001_fillHistos.C
#   inflating: root_build/tutorials/multicore/mt304_fillHistos.C
#   inflating: root_build/tutorials/multicore/mp105_processEntryList.C
#   inflating: root_build/tutorials/multicore/mp103_processSelector.C
#   inflating: root_build/tutorials/multicore/mp104_processH1.C
#   inflating: root_build/tutorials/multicore/mtbb201_parallelHistoFill.C
#   inflating: root_build/tutorials/multicore/mtbb001_fillHistos.C
#   inflating: root_build/tutorials/multicore/mp101_fillNtuples.C
#   inflating: root_build/tutorials/multicore/mtbb101_fillNtuples.C
#   inflating: root_build/tutorials/multicore/mp_H1_lambdas.C
#   inflating: root_build/tutorials/multicore/mt103_fillNtupleFromMultipleThreads.C
#    creating: root_build/tutorials/splot/
#   inflating: root_build/tutorials/splot/TestSPlot.C
#   inflating: root_build/tutorials/splot/TestSPlot_toyMC.dat
#    creating: root_build/tutorials/rcanvas/
#   inflating: root_build/tutorials/rcanvas/rh1.cxx
#   inflating: root_build/tutorials/rcanvas/rstyle.cxx
#   inflating: root_build/tutorials/rcanvas/rh1_large.cxx
#   inflating: root_build/tutorials/rcanvas/df105.json
#   inflating: root_build/tutorials/rcanvas/rh3_large.cxx
#   inflating: root_build/tutorials/rcanvas/subpads.cxx
#   inflating: root_build/tutorials/rcanvas/rh2.cxx
#   inflating: root_build/tutorials/rcanvas/rtext_align.cxx
#   inflating: root_build/tutorials/rcanvas/rframe.cxx
#   inflating: root_build/tutorials/rcanvas/th1_twoscales.cxx
#  extracting: root_build/tutorials/rcanvas/comic.woff2
#   inflating: root_build/tutorials/rcanvas/rh1_twoscales.cxx
#   inflating: root_build/tutorials/rcanvas/rh3.cxx
#   inflating: root_build/tutorials/rcanvas/rpave.cxx
#   inflating: root_build/tutorials/rcanvas/rline_width.cxx
#   inflating: root_build/tutorials/rcanvas/tobject.cxx
#   inflating: root_build/tutorials/rcanvas/rh2_large.cxx
#   inflating: root_build/tutorials/rcanvas/rh2_colz.cxx
#   inflating: root_build/tutorials/rcanvas/symlog.cxx
#   inflating: root_build/tutorials/rcanvas/raxis.cxx
#   inflating: root_build/tutorials/rcanvas/rbox.py
#   inflating: root_build/tutorials/rcanvas/rcanvas_mt.cxx
#   inflating: root_build/tutorials/rcanvas/rline.cxx
#   inflating: root_build/tutorials/rcanvas/rbox.cxx
#   inflating: root_build/tutorials/rcanvas/rtext_angle.cxx
#   inflating: root_build/tutorials/rcanvas/df104.py
#   inflating: root_build/tutorials/rcanvas/rmarker.cxx
#   inflating: root_build/tutorials/rcanvas/df105.py
#   inflating: root_build/tutorials/rcanvas/rline_style.cxx
#   inflating: root_build/tutorials/rcanvas/rpad.cxx
#   inflating: root_build/tutorials/rcanvas/rtext_font.cxx
#   inflating: root_build/tutorials/rcanvas/rlegend.cxx
#   inflating: root_build/tutorials/rcanvas/rcanvas_update.cxx
#    creating: root_build/tutorials/doc/
#    creating: root_build/tutorials/doc/v534/
#   inflating: root_build/tutorials/doc/v534/index.html
#    creating: root_build/tutorials/doc/v528/
#  extracting: root_build/tutorials/doc/v528/mass_spectrum.gif
#   inflating: root_build/tutorials/doc/v528/index.html
#    creating: root_build/tutorials/doc/v530/
#   inflating: root_build/tutorials/doc/v530/index.html
#    creating: root_build/tutorials/doc/v532/
#   inflating: root_build/tutorials/doc/v532/index.html
#    creating: root_build/tutorials/doc/v600/
#   inflating: root_build/tutorials/doc/v600/index.md
#    creating: root_build/tutorials/doc/v602/
#  extracting: root_build/tutorials/doc/v602/index.md
#    creating: root_build/tutorials/hist/
#   inflating: root_build/tutorials/hist/ratioplot1.py
#   inflating: root_build/tutorials/hist/th2polyBoxes.C
#   inflating: root_build/tutorials/hist/ratioplot6.C
#   inflating: root_build/tutorials/hist/FirstContour.C
#   inflating: root_build/tutorials/hist/hsumTimer.C
#   inflating: root_build/tutorials/hist/ratioplot4.py
#   inflating: root_build/tutorials/hist/movepalette.C
#   inflating: root_build/tutorials/hist/fillrandom.C
#   inflating: root_build/tutorials/hist/twoscales.C
#   inflating: root_build/tutorials/hist/candleplot.C
#   inflating: root_build/tutorials/hist/Fibonacci.C
#   inflating: root_build/tutorials/hist/hlHisto3.C
#   inflating: root_build/tutorials/hist/exec2.C
#   inflating: root_build/tutorials/hist/ZoomHistogram.C
#   inflating: root_build/tutorials/hist/candlescaled.C
#   inflating: root_build/tutorials/hist/fillrandom.py
#   inflating: root_build/tutorials/hist/histpalettecolor.C
#   inflating: root_build/tutorials/hist/sparsehist.C
#   inflating: root_build/tutorials/hist/hbars.C
#   inflating: root_build/tutorials/hist/twoscales.py
#   inflating: root_build/tutorials/hist/h2proj.C
#   inflating: root_build/tutorials/hist/logscales.C
#   inflating: root_build/tutorials/hist/transpad.C
#   inflating: root_build/tutorials/hist/ratioplot3.py
#   inflating: root_build/tutorials/hist/tprofile2polyRealisticModuleError.C
#   inflating: root_build/tutorials/hist/xyplot.C
#   inflating: root_build/tutorials/hist/hsum.C
#   inflating: root_build/tutorials/hist/NormalizeHistogram.C
#   inflating: root_build/tutorials/hist/testSmooth.C
#   inflating: root_build/tutorials/hist/ratioplot2.py
#   inflating: root_build/tutorials/hist/ratioplotOld.C
#   inflating: root_build/tutorials/hist/statsEditing.C
#   inflating: root_build/tutorials/hist/candleplotstack.C
#   inflating: root_build/tutorials/hist/cumulative.C
#   inflating: root_build/tutorials/hist/ratioplot3.C
#   inflating: root_build/tutorials/hist/exec1.C
#   inflating: root_build/tutorials/hist/ratioplot6.py
#   inflating: root_build/tutorials/hist/th2polyHoneycomb.C
#   inflating: root_build/tutorials/hist/ratioplot1.C
#   inflating: root_build/tutorials/hist/DynamicSlice.C
#   inflating: root_build/tutorials/hist/fillhistosauto2p.C
#   inflating: root_build/tutorials/hist/hlabels1.C
#   inflating: root_build/tutorials/hist/multicolor.C
#   inflating: root_build/tutorials/hist/hlHisto2.C
#   inflating: root_build/tutorials/hist/th2polyEurope.C
#   inflating: root_build/tutorials/hist/hlabels2.C
#   inflating: root_build/tutorials/hist/reverseaxis.C
#   inflating: root_build/tutorials/hist/thstack2palettecolor.C
#   inflating: root_build/tutorials/hist/tprofile2polyRealistic.C
#   inflating: root_build/tutorials/hist/thstackpalettecolor.C
#   inflating: root_build/tutorials/hist/hlHisto1.C
#   inflating: root_build/tutorials/hist/h1ReadAndDraw.C
#    creating: root_build/tutorials/hist/data/
#   inflating: root_build/tutorials/hist/data/tprofile2poly_tutorial.data
#   inflating: root_build/tutorials/hist/ratioplot5.C
#   inflating: root_build/tutorials/hist/ratioplot4.C
#   inflating: root_build/tutorials/hist/candlehisto.C
#   inflating: root_build/tutorials/hist/ratioplot5.py
#   inflating: root_build/tutorials/hist/candleplotwhiskers.C
#   inflating: root_build/tutorials/hist/ratioplot2.C
#   inflating: root_build/tutorials/hist/legendautoplaced.C
#   inflating: root_build/tutorials/hist/th2polyUSA.C
#   inflating: root_build/tutorials/hist/draw2dopt.C
#   inflating: root_build/tutorials/hist/rebin.C
#   inflating: root_build/tutorials/hist/ContourList.C
#   inflating: root_build/tutorials/hist/candleplotoption.C
#   inflating: root_build/tutorials/hist/hksimple.C
#   inflating: root_build/tutorials/hist/candledecay.C
#   inflating: root_build/tutorials/hist/hlHisto4.C
#   inflating: root_build/tutorials/hist/hstack.C
#    creating: root_build/tutorials/tmva/
#   inflating: root_build/tutorials/tmva/sigmoid-small.png
#   inflating: root_build/tutorials/tmva/TMVA_SOFIE_RDataFrame.py
#   inflating: root_build/tutorials/tmva/TMVAClassification.C
#   inflating: root_build/tutorials/tmva/TMVAClassificationCategory.C
#    creating: root_build/tutorials/tmva/keras/
#   inflating: root_build/tutorials/tmva/keras/ApplicationRegressionKeras.py
#   inflating: root_build/tutorials/tmva/keras/ApplicationClassificationKeras.py
#   inflating: root_build/tutorials/tmva/keras/index.md
#   inflating: root_build/tutorials/tmva/keras/RegressionKeras.py
#   inflating: root_build/tutorials/tmva/keras/MulticlassKeras.py
#   inflating: root_build/tutorials/tmva/keras/GenerateModel.py
#   inflating: root_build/tutorials/tmva/keras/ClassificationKeras.py
#   inflating: root_build/tutorials/tmva/TMVA_SOFIE_RSofieReader.C
#   inflating: root_build/tutorials/tmva/TMVAMulticlass.C
#   inflating: root_build/tutorials/tmva/tmva001_RTensor.C
#   inflating: root_build/tutorials/tmva/tmva003_RReader.C
#   inflating: root_build/tutorials/tmva/createData.C
#   inflating: root_build/tutorials/tmva/TMVAGAexample.C
#   inflating: root_build/tutorials/tmva/line-small.png
#   inflating: root_build/tutorials/tmva/tmva_logo.svg
#   inflating: root_build/tutorials/tmva/TMVA_SOFIE_Inference.py
#   inflating: root_build/tutorials/tmva/TMVARegression.C
#   inflating: root_build/tutorials/tmva/TMVACrossValidation.C
#   inflating: root_build/tutorials/tmva/tmva101_Training.py
#   inflating: root_build/tutorials/tmva/TMVA_SOFIE_ONNX.C
#   inflating: root_build/tutorials/tmva/makefile
#   inflating: root_build/tutorials/tmva/TMVA_SOFIE_PyTorch.C
#   inflating: root_build/tutorials/tmva/TMVA_RNN_Classification.C
#   inflating: root_build/tutorials/tmva/tmva002_RDataFrameAsTensor.C
#   inflating: root_build/tutorials/tmva/TMVARegressionApplication.C
#   inflating: root_build/tutorials/tmva/TMVACrossValidationRegression.C
#  extracting: root_build/tutorials/tmva/tmva_logo.gif
#   inflating: root_build/tutorials/tmva/TMVA_Higgs_Classification.C
#    creating: root_build/tutorials/tmva/envelope/
#   inflating: root_build/tutorials/tmva/envelope/index.md
#   inflating: root_build/tutorials/tmva/envelope/classification.C
# ...
#   inflating: root_build/include/TDataSetManagerFile.h
#   inflating: root_build/include/TMehrotraSolver.h
#   inflating: root_build/include/RooTrace.h
#   inflating: root_build/include/TEntryListFromFile.h
#   inflating: root_build/include/TStatus.h
#   inflating: root_build/include/TPacketizerFile.h
#   inflating: root_build/include/RooNLLVar.h
#   inflating: root_build/include/TProofBenchDataSet.h
#   inflating: root_build/include/TPgSQLResult.h
#   inflating: root_build/include/TMatrixTBase.h
#   inflating: root_build/include/TBufferJSON.h
#   inflating: root_build/include/TGuiFactory.h
#   inflating: root_build/include/TVirtualQConnection.h
#   inflating: root_build/include/TFoamMaxwt.h
#   inflating: root_build/include/TEllipse.h
#   inflating: root_build/include/TGraph2DErrors.h
#   inflating: root_build/include/TStorage.h
#   inflating: root_build/include/strlcpy.h
#   inflating: root_build/include/TMatrixDBase.h
#   inflating: root_build/include/TGuiBuilder.h
#   inflating: root_build/include/TImage.h
#   inflating: root_build/include/RooParamHistFunc.h
#   inflating: root_build/include/RooStepFunction.h
#   inflating: root_build/include/TTreeCacheUnzip.h
#   inflating: root_build/include/TCandle.h
#   inflating: root_build/include/TParticleClassPDG.h
#   inflating: root_build/include/TGedMarkerSelect.h
#   inflating: root_build/include/TGGC.h
#   inflating: root_build/include/RooIntegralMorph.h
#   inflating: root_build/include/TGeoParallelWorld.h
#   inflating: root_build/include/TBuffer.h
#   inflating: root_build/include/TVector2.h
#   inflating: root_build/include/Strlen.h
#   inflating: root_build/include/TMatrixFUtils.h
#   inflating: root_build/include/TGraphTime.h
#   inflating: root_build/include/TExec.h
#   inflating: root_build/include/TDataSetManager.h
#   inflating: root_build/include/TIndArray.h
#   inflating: root_build/include/TVirtualViewer3D.h
#   inflating: root_build/include/TPgSQLServer.h
#   inflating: root_build/include/TGDockableFrame.h
#   inflating: root_build/include/TContainerConverters.h
#   inflating: root_build/include/RooFunctor.h
#   inflating: root_build/include/TThreadImp.h
#   inflating: root_build/include/TTeXDump.h
#   inflating: root_build/include/THttpCallArg.h
#   inflating: root_build/include/TGWindow.h
#   inflating: root_build/include/TCONS.h
#   inflating: root_build/include/TBranchCacheInfo.h
#   inflating: root_build/include/TTreeViewer.h
#   inflating: root_build/include/TSpectrum3.h
#   inflating: root_build/include/TNodeDiv.h
#   inflating: root_build/include/TLeafF.h
#   inflating: root_build/include/RooExtendedTerm.h
#   inflating: root_build/include/TFitResultPtr.h
#   inflating: root_build/include/Compression.h
#   inflating: root_build/include/TSAXParser.h
#   inflating: root_build/include/TEntryListBlock.h
#   inflating: root_build/include/RooLandau.h
#   inflating: root_build/include/TApplication.h
#   inflating: root_build/include/TRootGuiBuilder.h
#   inflating: root_build/include/TS3HTTPRequest.h
#   inflating: root_build/include/TNtuple.h
#   inflating: root_build/include/TBranchSTL.h
#   inflating: root_build/include/TPRegexp.h
#   inflating: root_build/include/TArrayC.h
#   inflating: root_build/include/RooGaussModel.h
#   inflating: root_build/include/TGridCollection.h
#   inflating: root_build/include/TLeafO.h
#   inflating: root_build/include/TGeoTubeEditor.h
#   inflating: root_build/include/THttpEngine.h
#   inflating: root_build/include/TNetFileStager.h
#    creating: root_build/include/XrdOfs/
#   inflating: root_build/include/XrdOfs/XrdOfsPrepare.hh
#   inflating: root_build/include/XrdOfs/XrdOfsFSctl_PI.hh
#   inflating: root_build/include/TClassDocOutput.h
#   inflating: root_build/include/RooNumCdf.h
#   inflating: root_build/include/TF1NormSum.h
#   inflating: root_build/include/TBasket.h
#   inflating: root_build/include/TMatrixFfwd.h
#   inflating: root_build/include/THnSparse_Internal.h
#   inflating: root_build/include/TG3DLine.h
#   inflating: root_build/include/RooJohnson.h
#   inflating: root_build/include/RooCollectionProxy.h
#   inflating: root_build/include/TGTableContainer.h
#   inflating: root_build/include/TMatrixFSymfwd.h
#   inflating: root_build/include/TDecompSparse.h
#   inflating: root_build/include/TStreamerInfoActions.h
#   inflating: root_build/include/TGToolTip.h
#   inflating: root_build/include/TUnuranContDist.h
#   inflating: root_build/include/TGeoChecker.h
#   inflating: root_build/include/RooAbsSelfCachedPdf.h
#   inflating: root_build/include/TIterator.h
#   inflating: root_build/include/TMemberInspector.h
#   inflating: root_build/include/TFileInfo.h
#   inflating: root_build/include/TLeafI.h
#   inflating: root_build/include/HelpTextTV.h
#   inflating: root_build/include/TQueryResultManager.h
#   inflating: root_build/include/TGridJob.h
#   inflating: root_build/include/TSeqCollection.h
#   inflating: root_build/include/TGHtmlTokens.h
#   inflating: root_build/include/RooFunctor1DBinding.h
#    creating: root_build/bin/
#   inflating: root_build/bin/setxrd.sh
#   inflating: root_build/bin/rootssh
#   inflating: root_build/bin/rooteventselector
#   inflating: root_build/bin/root.exe
#   inflating: root_build/bin/roots.exe
#   inflating: root_build/bin/roots
#   inflating: root_build/bin/rootbrowse
#   inflating: root_build/bin/rootcling
#   inflating: root_build/bin/thisroot.fish
#   inflating: root_build/bin/rootprint
#   inflating: root_build/bin/rootcint
#   inflating: root_build/bin/proofserv.exe
#   inflating: root_build/bin/rmkdepend
#   inflating: root_build/bin/xpdtest
#   inflating: root_build/bin/rootrm
#   inflating: root_build/bin/rootmkdir
#   inflating: root_build/bin/rootnb.exe
#   inflating: root_build/bin/genreflex
#   inflating: root_build/bin/rootdrawtree
#   inflating: root_build/bin/rootslimtree
#   inflating: root_build/bin/rootls
#   inflating: root_build/bin/setxrd.csh
#   inflating: root_build/bin/root
#   inflating: root_build/bin/rootcp
#   inflating: root_build/bin/thisroot.csh
#   inflating: root_build/bin/rootn.exe
#   inflating: root_build/bin/hadd
#   inflating: root_build/bin/root-config
#   inflating: root_build/bin/proofserv
#   inflating: root_build/bin/rootmv
#   inflating: root_build/bin/prepareHistFactory
#   inflating: root_build/bin/rootreadspeed
#   inflating: root_build/bin/hist2workspace
#   inflating: root_build/bin/thisroot.sh
#    creating: root_build/cmake/
#   inflating: root_build/cmake/ROOTConfig-targets.cmake
#   inflating: root_build/cmake/ROOTConfig-version.cmake
#   inflating: root_build/cmake/ROOTConfig.cmake
#   inflating: root_build/cmake/RootTestDriver.cmake
#   inflating: root_build/cmake/ROOTUseFile.cmake
#   inflating: root_build/cmake/RootMacros.cmake
#   inflating: root_build/cmake/ROOTConfig-targets-release.cmake
#   inflating: root_build/LICENSE
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# g++ is already the newest version (4:11.2.0-1ubuntu1).
# g++ set to manually installed.
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gcc set to manually installed.
# gfortran is already the newest version (4:11.2.0-1ubuntu1).
# libxext-dev is already the newest version (2:1.3.4-1build1).
# libxext-dev set to manually installed.
# libxft-dev is already the newest version (2.3.4-1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# libx11-dev is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-dev set to manually installed.
# The following additional packages will be installed:
#   binutils-common binutils-x86-64-linux-gnu libapr1 libaprutil1 libbinutils libctf0 libdpkg-perl
#   libserf-1-1 libsvn1 libutf8proc2
# Suggested packages:
#   binutils-doc debian-keyring bzr db5.3-util libapache2-mod-svn subversion-tools ncompress
#   tar-scripts tar-doc
# Recommended packages:
#   fakeroot libalgorithm-merge-perl libfile-fcntllock-perl liblocale-gettext-perl
# The following NEW packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1 libutf8proc2 libxpm-dev subversion
# The following packages will be upgraded:
#   binutils binutils-common binutils-x86-64-linux-gnu dpkg-dev libbinutils libctf0 libdpkg-perl tar
# 8 upgraded, 7 newly installed, 0 to remove and 37 not upgraded.
# Need to get 7,533 kB of archives.
# After this operation, 10.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 tar amd64 1.34+dfsg-1ubuntu0.1.22.04.2 [295 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libctf0 amd64 2.38-4ubuntu2.6 [103 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.38-4ubuntu2.6 [2,326 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libbinutils amd64 2.38-4ubuntu2.6 [662 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils amd64 2.38-4ubuntu2.6 [3,200 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-common amd64 2.38-4ubuntu2.6 [222 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dpkg-dev all 1.21.1ubuntu2.3 [922 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdpkg-perl all 1.21.1ubuntu2.3 [237 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libapr1 amd64 1.7.0-8ubuntu0.22.04.1 [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libaprutil1 amd64 1.6.1-5ubuntu4.22.04.2 [92.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libserf-1-1 amd64 1.3.9-10ubuntu2 [50.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libutf8proc2 amd64 2.7.0-3 [73.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsvn1 amd64 1.14.1-3ubuntu0.22.04.1 [1,387 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxpm-dev amd64 1:3.5.12-1ubuntu0.22.04.2 [90.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 subversion amd64 1.14.1-3ubuntu0.22.04.1 [960 kB]
# Fetched 7,533 kB in 1s (10.3 MB/s)
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../tar_1.34+dfsg-1ubuntu0.1.22.04.2_amd64.deb ...
# Unpacking tar (1.34+dfsg-1ubuntu0.1.22.04.2) over (1.34+dfsg-1ubuntu0.1.22.04.1) ...
# Setting up tar (1.34+dfsg-1ubuntu0.1.22.04.2) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../00-libctf0_2.38-4ubuntu2.6_amd64.deb ...
# Unpacking libctf0:amd64 (2.38-4ubuntu2.6) over (2.38-4ubuntu2.3) ...
# Preparing to unpack .../01-binutils-x86-64-linux-gnu_2.38-4ubuntu2.6_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.38-4ubuntu2.6) over (2.38-4ubuntu2.3) ...
# Preparing to unpack .../02-libbinutils_2.38-4ubuntu2.6_amd64.deb ...
# Unpacking libbinutils:amd64 (2.38-4ubuntu2.6) over (2.38-4ubuntu2.3) ...
# Preparing to unpack .../03-binutils_2.38-4ubuntu2.6_amd64.deb ...
# Unpacking binutils (2.38-4ubuntu2.6) over (2.38-4ubuntu2.3) ...
# Preparing to unpack .../04-binutils-common_2.38-4ubuntu2.6_amd64.deb ...
# Unpacking binutils-common:amd64 (2.38-4ubuntu2.6) over (2.38-4ubuntu2.3) ...
# Preparing to unpack .../05-dpkg-dev_1.21.1ubuntu2.3_all.deb ...
# Unpacking dpkg-dev (1.21.1ubuntu2.3) over (1.21.1ubuntu2.2) ...
# Preparing to unpack .../06-libdpkg-perl_1.21.1ubuntu2.3_all.deb ...
# Unpacking libdpkg-perl (1.21.1ubuntu2.3) over (1.21.1ubuntu2.2) ...
# Selecting previously unselected package libapr1:amd64.
# Preparing to unpack .../07-libapr1_1.7.0-8ubuntu0.22.04.1_amd64.deb ...
# Unpacking libapr1:amd64 (1.7.0-8ubuntu0.22.04.1) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../08-libaprutil1_1.6.1-5ubuntu4.22.04.2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-5ubuntu4.22.04.2) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../09-libserf-1-1_1.3.9-10ubuntu2_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-10ubuntu2) ...
# Selecting previously unselected package libutf8proc2:amd64.
# Preparing to unpack .../10-libutf8proc2_2.7.0-3_amd64.deb ...
# Unpacking libutf8proc2:amd64 (2.7.0-3) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../11-libsvn1_1.14.1-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsvn1:amd64 (1.14.1-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libxpm-dev:amd64.
# Preparing to unpack .../12-libxpm-dev_1%3a3.5.12-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Selecting previously unselected package subversion.
# Preparing to unpack .../13-subversion_1.14.1-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking subversion (1.14.1-3ubuntu0.22.04.1) ...
# Setting up libutf8proc2:amd64 (2.7.0-3) ...
# Setting up binutils-common:amd64 (2.38-4ubuntu2.6) ...
# Setting up libapr1:amd64 (1.7.0-8ubuntu0.22.04.1) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Setting up libdpkg-perl (1.21.1ubuntu2.3) ...
# Setting up libbinutils:amd64 (2.38-4ubuntu2.6) ...
# Setting up libaprutil1:amd64 (1.6.1-5ubuntu4.22.04.2) ...
# Setting up libctf0:amd64 (2.38-4ubuntu2.6) ...
# Setting up libserf-1-1:amd64 (1.3.9-10ubuntu2) ...
# Setting up libsvn1:amd64 (1.14.1-3ubuntu0.22.04.1) ...
# Setting up binutils-x86-64-linux-gnu (2.38-4ubuntu2.6) ...
# Setting up subversion (1.14.1-3ubuntu0.22.04.1) ...
# Setting up binutils (2.38-4ubuntu2.6) ...
# Setting up dpkg-dev (1.21.1ubuntu2.3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# --2024-06-18 06:21:29--  http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 91.189.91.82, 91.189.91.83, 185.125.190.81, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|91.189.91.82|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318204 (1.3M) [application/vnd.debian.binary-package]
# Saving to: ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’
#
# libssl1.1_1.1.1f-1u 100%[===================>]   1.26M  5.52MB/s    in 0.2s
#
# 2024-06-18 06:21:30 (5.52 MB/s) - ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’ saved [1318204/1318204]
#
# Selecting previously unselected package libssl1.1:amd64.
# (Reading database ... 122063 files and directories currently installed.)
# Preparing to unpack libssl1.1_1.1.1f-1ubuntu2_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# Setting up libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Welcome to JupyROOT 6.28/04

# %%
#Let's have a look at the mass variable in the file f
from ROOT import TFile, TCanvas, TLine, TArrow
f = TFile.Open("/content/drive/MyDrive/data.root")
t = f.Get("ntp")
fmc = TFile.Open("/content/drive/MyDrive/mc.root")
tmc = fmc.Get("ntp")

cmass = TCanvas("BmassCanvas","Canvassss",1000,600)
t.Draw("mass")

#line2 = TLine(5.5, 0, 5.5, 24000)
#line2.SetLineColor(2)
#line2.SetLineWidth(2)
#line2.Draw()
#arrow2 = TArrow(5.5,12000,5.7,12000,0.02,"|>")
#arrow2.SetLineColor(2)
#arrow2.SetFillColor(2)
#arrow2.SetLineWidth(2)
#arrow2.Draw()

cmass.Draw()

# %%
#Open a temporary file. The option RECREATE means that if the file does not exist
#then it is created from scratch; otherwise, if it exists, it will be overwritten.
#Other possible options can be found here: https://root.cern.ch/doc/master/classTFile.html#ad0377adf2f3d88da1a1f77256a140d60
f_temp = TFile.Open("/content/drive/MyDrive/data_bkg.root","RECREATE")
#Select the file you just created
f_temp.cd()
#Copy the TTree in the data.root file in another temporary TTree. Specify your selection.
t_temp = t.CopyTree("mass>5.5")
#Write the new TTree in the new TFile. Closing the TFile will ensure that all modifications will be saved.
f_temp.Write()
f_temp.Close()

# %%
#Check that everything is fine: open the file and look at the mass variable
f_bkg = TFile.Open("/content/drive/MyDrive/data_bkg.root")
t_bkg = f_bkg.Get("ntp")
c_bkg = TCanvas("c_bkg","Check",1000,600)
t_bkg.Draw("mass")
c_bkg.Draw()

# %%
from ROOT import TMVA

help(TMVA.Types.EMVA)
#types = dir(TMVA.Types) #list all attributes of the class TMVA.Types
#list_types = [x for x in types if x[0]=="k"] #select only variables starting with "k"
#list_types
#help(TMVA.Types)
# Out:
# Help on class EMVA in module __main__:
#
# class EMVA(builtins.int)
#  |  Method resolution order:
#  |      EMVA
#  |      builtins.int
#  |      builtins.object
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __cpp_name__ = 'TMVA::Types::EMVA'
#  |
#  |  kBDT = 9
#  |
#  |  kBayesClassifier = 14
#  |
#  |  kBoost = 16
#  |
#  |  kC50 = 28
#  |
#  |  kCFMlpANN = 7
#  |
#  |  kCategory = 20
#  |
#  |  kCrossValidation = 32
#  |
#  |  kCuts = 1
#  |
#  |  kDL = 22
#  |
#  |  kDNN = 21
#  |
#  |  kDT = 10
#  |
#  |  kFDA = 15
#  |
#  |  kFisher = 5
#  |
#  |  kHMatrix = 4
#  |
#  |  kKNN = 6
#  |
#  |  kLD = 18
#  |
#  |  kLikelihood = 2
#  |
#  |  kMLP = 13
#  |
#  |  kMaxMethod = 33
#  |
#  |  kPDEFoam = 17
#  |
#  |  kPDERS = 3
#  |
#  |  kPlugins = 19
#  |
#  |  kPyAdaBoost = 24
#  |
#  |  kPyGTB = 25
#  |
#  |  kPyKeras = 26
#  |
#  |  kPyRandomForest = 23
#  |
#  |  kPyTorch = 27
#  |
#  |  kRSNNS = 29
#  |
#  |  kRSVM = 30
#  |
#  |  kRXGB = 31
#  |
#  |  kRuleFit = 11
#  |
#  |  kSVM = 12
#  |
#  |  kTMlpANN = 8
#  |
#  |  kVariable = 0
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.int:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(self, /)
#  |      Returns size in memory, in bytes.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  as_integer_ratio(self, /)
#  |      Return integer ratio.
#  |
#  |      Return a pair of integers, whose ratio is exactly equal to the original int
#  |      and with a positive denominator.
#  |
#  |      >>> (10).as_integer_ratio()
#  |      (10, 1)
#  |      >>> (-10).as_integer_ratio()
#  |      (-10, 1)
#  |      >>> (0).as_integer_ratio()
#  |      (0, 1)
#  |
#  |  bit_count(self, /)
#  |      Number of ones in the binary representation of the absolute value of self.
#  |
#  |      Also known as the population count.
#  |
#  |      >>> bin(13)
#  |      '0b1101'
#  |      >>> (13).bit_count()
#  |      3
#  |
#  |  bit_length(self, /)
#  |      Number of bits necessary to represent self in binary.
#  |
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  to_bytes(self, /, length, byteorder, *, signed=False)
#  |      Return an array of bytes representing an integer.
#  |
#  |      length
#  |        Length of bytes object to use.  An OverflowError is raised if the
#  |        integer is not representable with the given number of bytes.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Determines whether two's complement is used to represent the integer.
#  |        If signed is False and a negative integer is given, an OverflowError
#  |        is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from builtins.int:
#  |
#  |  from_bytes(bytes, byteorder, *, signed=False) from __main__.EMVA_meta
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      bytes
#  |        Holds the array of bytes to convert.  The argument must either
#  |        support the buffer protocol or be an iterable object producing bytes.
#  |        Bytes and bytearray are examples of built-in objects that support the
#  |        buffer protocol.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Indicates whether two's complement is used to represent the integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.int:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from builtins.int:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number

# %%
#Let's import the TMVA module (MultiVariateAnalysis)
from ROOT import TMVA
TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

#Create a new file for the outputs of the classifiers
output = ROOT.TFile.Open('TMVA.root', 'RECREATE')

#Initialise the TMVA factory, which will be out human-to-algorithm interface.
#On top of the namme of the file you can add some options and configurations.
#You can find all info in the TMVA manual: https://root.cern.ch/download/doc/tmva/TMVAUsersGuide.pdf
factory = TMVA.Factory('TMVAClassification', output,'!V:!Silent:Color:DrawProgressBar:Transformations=I,D,G:AnalysisType=Classification')


#Initialise the DataLoader, which is needed to load the two TTrees and to specify
#which variables you want to use to train your BDT.
#In principle you can also use all the variables in your TTree, but in that case
#the algotirhm will be VERY slow and the risk of overtraining will be higher.

#Remember not to use the mass variable!

dataloader = TMVA.DataLoader('dataset')
dataloader.AddVariable("minPT")
dataloader.AddVariable("maxPT")
dataloader.AddVariable("minIPCHI2")
dataloader.AddVariable("maxIPCHI2")
dataloader.AddVariable("doca")
dataloader.AddVariable("vertexCHI2")
dataloader.AddSignalTree(tmc,1.0)
dataloader.AddBackgroundTree(t_bkg, 1.0)

#Prepare the data for the MVA. They are split in two: a training subsample and a testing subsample.
#The training sample will be use for the training and the testing will be used later.
#You can also add a common selection as a TCut.
dataloader.PrepareTrainingAndTestTree(ROOT.TCut(''), "SplitMode=Random:NormMode=NumEvents:!V" );

#Load the DataLoader in the Factory and specify which algorithms you want to use.
#You can use default options by not specifying anything in the option field or you can
#try to experiment different configurations: see the TMVA note.
#As an example, here is a BDT with some standard options, separated by ":".
factory.BookMethod(dataloader, TMVA.Types.kBDT, "BDT", "!H:!V:NTrees=200:MinNodeSize=2.5%:MaxDepth=3:BoostType=Grad:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20" )

#you can add other methods. Try a variety of them so you can check
#factory.BookMethod(dataloader, TMVA.Types.kFisher, "fisher")
#factory.BookMethod(dataloader, TMVA.Types.kSVM,"SVM")
#factory.BookMethod(dataloader, TMVA.Types.kMLP,"MLP")
#factory.BookMethod(dataloader, TMVA.Types.kKNN,"KNN")
#factory.BookMethod(dataloader, TMVA.Types.kTMlpANN,"ANN")
# Out:
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree ntp of type Signal with 238591 events
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree ntp of type Background with 124944 events
#                          : Dataset[dataset] : Class index : 0  name : Signal
#                          : Dataset[dataset] : Class index : 1  name : Background
# Factory                  : Booking method: BDT
#                          :
#                          : the option NegWeightTreatment=InverseBoostNegWeights does not exist for BoostType=Grad
#                          : --> change to new default NegWeightTreatment=Pray
#                          : Rebuilding Dataset dataset
#                          : Building event vectors for type 2 Signal
#                          : Dataset[dataset] :  create input formulas for tree ntp
#                          : Building event vectors for type 2 Background
#                          : Dataset[dataset] :  create input formulas for tree ntp
# DataSetFactory           : [dataset] : Number of events in input trees
#                          :
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Signal     -- training events            : 119295
#                          : Signal     -- testing events             : 119295
#                          : Signal     -- training and testing events: 238590
#                          : Background -- training events            : 62472
#                          : Background -- testing events             : 62472
#                          : Background -- training and testing events: 124944
#                          :
# DataSetInfo              : Correlation matrix (Signal):
#                          : ------------------------------------------------------------------
#                          :               minPT   maxPT minIPCHI2 maxIPCHI2    doca vertexCHI2
#                          :      minPT:  +1.000  +0.313    +0.129    -0.000  -0.201     +0.050
#                          :      maxPT:  +0.313  +1.000    +0.066    +0.034  -0.123     +0.025
#                          :  minIPCHI2:  +0.129  +0.066    +1.000    +0.611  -0.059     +0.014
#                          :  maxIPCHI2:  -0.000  +0.034    +0.611    +1.000  -0.027     +0.006
#                          :       doca:  -0.201  -0.123    -0.059    -0.027  +1.000     +0.761
#                          : vertexCHI2:  +0.050  +0.025    +0.014    +0.006  +0.761     +1.000
#                          : ------------------------------------------------------------------
# DataSetInfo              : Correlation matrix (Background):
#                          : ------------------------------------------------------------------
#                          :               minPT   maxPT minIPCHI2 maxIPCHI2    doca vertexCHI2
#                          :      minPT:  +1.000  -0.171    +0.151    -0.067  -0.032     +0.251
#                          :      maxPT:  -0.171  +1.000    +0.090    -0.061  +0.130     +0.179
#                          :  minIPCHI2:  +0.151  +0.090    +1.000    +0.431  +0.038     +0.126
#                          :  maxIPCHI2:  -0.067  -0.061    +0.431    +1.000  +0.041     +0.023
#                          :       doca:  -0.032  +0.130    +0.038    +0.041  +1.000     +0.722
#                          : vertexCHI2:  +0.251  +0.179    +0.126    +0.023  +0.722     +1.000
#                          : ------------------------------------------------------------------
# DataSetFactory           : [dataset] :
#                          :

# %%
factory.TrainAllMethods()
factory.TestAllMethods()
factory.EvaluateAllMethods()

output.Close()
# Out:
# Factory                  : Train all methods
# Factory                  : [dataset] : Create Transformation "I" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'minPT' <---> Output : variable 'minPT'
#                          : Input : variable 'maxPT' <---> Output : variable 'maxPT'
#                          : Input : variable 'minIPCHI2' <---> Output : variable 'minIPCHI2'
#                          : Input : variable 'maxIPCHI2' <---> Output : variable 'maxIPCHI2'
#                          : Input : variable 'doca' <---> Output : variable 'doca'
#                          : Input : variable 'vertexCHI2' <---> Output : variable 'vertexCHI2'
# Factory                  : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'minPT' <---> Output : variable 'minPT'
#                          : Input : variable 'maxPT' <---> Output : variable 'maxPT'
#                          : Input : variable 'minIPCHI2' <---> Output : variable 'minIPCHI2'
#                          : Input : variable 'maxIPCHI2' <---> Output : variable 'maxIPCHI2'
#                          : Input : variable 'doca' <---> Output : variable 'doca'
#                          : Input : variable 'vertexCHI2' <---> Output : variable 'vertexCHI2'
# Factory                  : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'minPT' <---> Output : variable 'minPT'
#                          : Input : variable 'maxPT' <---> Output : variable 'maxPT'
#                          : Input : variable 'minIPCHI2' <---> Output : variable 'minIPCHI2'
#                          : Input : variable 'maxIPCHI2' <---> Output : variable 'maxIPCHI2'
#                          : Input : variable 'doca' <---> Output : variable 'doca'
#                          : Input : variable 'vertexCHI2' <---> Output : variable 'vertexCHI2'
#                          : Preparing the Decorrelation transformation...
#                          : Preparing the Gaussian transformation...
# TFHandler_Factory        :   Variable          Mean          RMS   [        Min          Max ]
#                          : ---------------------------------------------------------------------
#                          :      minPT:   0.0024359     0.99547   [     -3.2990      5.7307 ]
#                          :      maxPT:   0.0024360     0.99544   [     -3.2990      5.7307 ]
#                          :  minIPCHI2:   0.0024974     0.99559   [     -3.2990      5.7307 ]
#                          :  maxIPCHI2:   0.0029013     0.99472   [     -4.0959      5.7307 ]
#                          :       doca:   0.0025268     0.99586   [     -3.2990      5.7307 ]
#                          : vertexCHI2:   0.0025787     0.99552   [     -3.2983      5.7307 ]
#                          : ---------------------------------------------------------------------
#                          : Ranking input variables (method unspecific)...
# Id_Deco_GaussTransform...: Ranking result (top variable is best ranked)
#                          : -----------------------------------
#                          : Rank : Variable   : Separation
#                          : -----------------------------------
#                          :    1 : minIPCHI2  : 1.831e-01
#                          :    2 : maxIPCHI2  : 1.537e-01
#                          :    3 : maxPT      : 1.428e-01
#                          :    4 : minPT      : 1.038e-01
#                          :    5 : doca       : 5.794e-02
#                          :    6 : vertexCHI2 : 4.020e-02
#                          : -----------------------------------
# Factory                  : Train method: BDT for Classification
#                          :
# BDT                      : #events: (reweighted) sig: 90883.5 bkg: 90883.5
#                          : #events: (unweighted) sig: 119295 bkg: 62472
#                          : Training 200 Decision Trees ... patience please
#                          : Elapsed time for training with 181767 events: 33.2 sec
# BDT                      : [dataset] : Evaluation of BDT on training sample (181767 events)
#                          : Elapsed time for evaluation of 181767 events: 2 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDT.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDT.class.C
#                          : TMVA.root:/dataset/Method_BDT/BDT
# Factory                  : Training finished
#                          :
#                          : Ranking input variables (method specific)...
# BDT                      : Ranking result (top variable is best ranked)
#                          : --------------------------------------------
#                          : Rank : Variable   : Variable Importance
#                          : --------------------------------------------
#                          :    1 : doca       : 2.602e-01
#                          :    2 : minPT      : 2.440e-01
#                          :    3 : maxPT      : 2.335e-01
#                          :    4 : vertexCHI2 : 1.238e-01
#                          :    5 : minIPCHI2  : 7.154e-02
#                          :    6 : maxIPCHI2  : 6.695e-02
#                          : --------------------------------------------
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
#                          : Reading weight file: dataset/weights/TMVAClassification_BDT.weights.xml
# Factory                  : Test all methods
# Factory                  : Test method: BDT for Classification performance
#                          :
# BDT                      : [dataset] : Evaluation of BDT on testing sample (181767 events)
#                          : Elapsed time for evaluation of 181767 events: 1.81 sec
# Factory                  : Evaluate all methods
# Factory                  : Evaluate classifier: BDT
#                          :
# BDT                      : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDT            :   Variable          Mean          RMS   [        Min          Max ]
#                          : ---------------------------------------------------------------------
#                          :      minPT:      2.3995      1.0659   [      1.0000      12.684 ]
#                          :      maxPT:      4.7302      1.7392   [      1.6168      21.285 ]
#                          :  minIPCHI2:      719.97      1683.3   [      4.0066  1.2567e+05 ]
#                          :  maxIPCHI2:      2533.8      5909.2   [      7.6822  8.2042e+05 ]
#                          :       doca:    0.024005    0.020369   [  3.0892e-07    0.099999 ]
#                          : vertexCHI2:      1.7498      2.9902   [  2.9503e-10      81.267 ]
#                          : ---------------------------------------------------------------------
#                          :
#                          : Evaluation results ranked by best signal efficiency and purity (area)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet       MVA
#                          : Name:         Method:          ROC-integ
#                          : dataset       BDT            : 0.898
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Testing efficiency compared to training efficiency (overtraining check)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
#                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : dataset              BDT            : 0.417 (0.427)       0.743 (0.747)      0.880 (0.882)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
# Dataset:dataset          : Created tree 'TestTree' with 181767 events
#                          :
# Dataset:dataset          : Created tree 'TrainTree' with 181767 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html
# 0%, time left: unknown
# 7%, time left: 27 sec
# 13%, time left: 25 sec
# 19%, time left: 22 sec
# 25%, time left: 21 sec
# 32%, time left: 19 sec
# 38%, time left: 18 sec
# 44%, time left: 17 sec
# 50%, time left: 15 sec
# 57%, time left: 13 sec
# 63%, time left: 11 sec
# 69%, time left: 9 sec
# 75%, time left: 7 sec
# 82%, time left: 5 sec
# 88%, time left: 3 sec
# 94%, time left: 1 sec
# 0%, time left: unknown
# 6%, time left: 1 sec
# 12%, time left: 1 sec
# 18%, time left: 1 sec
# 25%, time left: 1 sec
# 31%, time left: 1 sec
# 37%, time left: 1 sec
# 43%, time left: 1 sec
# 50%, time left: 0 sec
# 56%, time left: 0 sec
# 62%, time left: 0 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 1 sec
# 12%, time left: 1 sec
# 18%, time left: 1 sec
# 25%, time left: 1 sec
# 31%, time left: 1 sec
# 37%, time left: 1 sec
# 43%, time left: 1 sec
# 50%, time left: 0 sec
# 56%, time left: 0 sec
# 62%, time left: 0 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec

# %%
roc = factory.GetROCCurve(dataloader)
roc.Draw()
method_list=["BDT"] #add in this list all the methods you trained
for m in method_list:
  AUC = factory.GetROCIntegral(dataloader,m)
  print("Method: " + m + ", AUC: " + str(AUC))
# Out:
# Method: BDT, AUC: 0.8975714828780741

# %%
#After executing the MVA code, a new file called TMVAClassification_BDT.weights.xml is created in the
#dataset/weights/ folder in your Drive (replace "BDT" with your favourite MVA method).
#This file contains the results of the MVA training and is used to classify the data events.
#Just like in the training, each event will be associated with a MVA output value
#according to how much the event looks like signal or background.
#
#First import the array module: this is a technical step due to how TMVA is ported in python.
from array import array
from ROOT import TMVA, TFile

f = ROOT.TFile.Open("/content/drive/MyDrive/data.root")
t = f.Get("ntp")
fmva = ROOT.TFile.Open("TMVA.root")
tmva=fmva.Get("dataset/TrainTree")
t.Print()

#Now initialise the TMVA Reader, which can read the .xml file
reader = TMVA.Reader("!Silent")

#The next lines will match the variables used in the training with the variables
#in the TTree of the data sample.
forbiddenList=["classID", "className", "weight", "BDT"]
br = {}

for branch in tmva.GetListOfBranches():
  branchName = branch.GetName()
  print(branchName)
  if branchName not in forbiddenList:
    if branchName=="piplusP": #there was a problem with the piplusP variable when the ntuple was created, please ignore this
      br[branchName] = array('d', [-999.])
    else:
      br[branchName] = array('f', [-999.])
    reader.AddVariable(branchName, br[branchName])
    t.SetBranchAddress(branchName, br[branchName])

#Now we need to tell the reader which MVA method and which weights file to use.
#Change the name "BDT" (also in the weights file) with the name of your classifier
reader.BookMVA("BDT", "dataset/weights/TMVAClassification_BDT.weights.xml")

#Create the new file and the new TTree
newFile = ROOT.TFile.Open("/content/drive/MyDrive/data_for_fit.root","RECREATE")
newTree = ROOT.TTree("ntp", "ntp")

#define some variables
mass = array('f', [0.])
tag = array('i', [0])

newmass = array('f', [0.])
newtag = array('i', [0])
MVA = array('f',[0])

#Connect these variables with the ones in the TTree
t.SetBranchAddress("mass",mass)
t.SetBranchAddress("tag",tag)

#Create new branches in the new TTree with the variables we want
massbranch = newTree.Branch("mass", newmass, "mass/F")
tagbranch = newTree.Branch("tag", newtag, "tag/I")
MVAbranch = newTree.Branch("MVA", MVA, "MVA/F")

#Let's start! We loop over all the events in the TTree t and for each of them we
#fill the new tree with the variables of interest
n = t.GetEntries()
for i in range(n):
    t.GetEntry(i)
    MVA[0] = reader.EvaluateMVA("BDT") #here the MVA is evaluated for the event i
    newmass[0] = mass[0]
    newtag[0] = tag[0]
    newTree.Fill()

#finally, write the new file and close it
newFile.Write("",TFile.kOverwrite)
newFile.Close()
# Out:
# classID
# className
# minPT
# maxPT
# minIPCHI2
# maxIPCHI2
# doca
# vertexCHI2
# weight
# BDT
# ******************************************************************************
# *Tree    :ntp       : ntp                                                    *
# *Entries :   535088 : Total =        64326539 bytes  File  Size =   55692889 *
# *        :          : Tree compression factor =   1.15                       *
# ******************************************************************************
# *Br    0 :minPT     : minPT/F                                                *
# *Entries :   535088 : Total  Size=    2144115 bytes  File Size  =    1898894 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.13     *
# *............................................................................*
# *Br    1 :minIP     : minIP/F                                                *
# *Entries :   535088 : Total  Size=    2144115 bytes  File Size  =    1883295 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.14     *
# *............................................................................*
# *Br    2 :minIPCHI2 : minIPCHI2/F                                            *
# *Entries :   535088 : Total  Size=    2144283 bytes  File Size  =    1966326 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    3 :maxPT     : maxPT/F                                                *
# *Entries :   535088 : Total  Size=    2144115 bytes  File Size  =    1855685 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.15     *
# *............................................................................*
# *Br    4 :maxIP     : maxIP/F                                                *
# *Entries :   535088 : Total  Size=    2144115 bytes  File Size  =    1911329 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.12     *
# *............................................................................*
# *Br    5 :maxIPCHI2 : maxIPCHI2/F                                            *
# *Entries :   535088 : Total  Size=    2144283 bytes  File Size  =    1954083 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.10     *
# *............................................................................*
# *Br    6 :doca      : doca/F                                                 *
# *Entries :   535088 : Total  Size=    2144073 bytes  File Size  =    1945685 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.10     *
# *............................................................................*
# *Br    7 :vertexCHI2 : vertexCHI2/F                                          *
# *Entries :   535088 : Total  Size=    2144325 bytes  File Size  =    1991462 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.08     *
# *............................................................................*
# *Br    8 :bPT       : bPT/F                                                  *
# *Entries :   535088 : Total  Size=    2144031 bytes  File Size  =    1917302 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.12     *
# *............................................................................*
# *Br    9 :bIP       : bIP/F                                                  *
# *Entries :   535088 : Total  Size=    2144031 bytes  File Size  =    1917393 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   10 :bIPCHI2   : bIPCHI2/F                                              *
# *Entries :   535088 : Total  Size=    2144199 bytes  File Size  =    1970620 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.09     *
# *............................................................................*
# *Br   11 :bFD       : bFD/F                                                  *
# *Entries :   535088 : Total  Size=    2144031 bytes  File Size  =    1921044 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   12 :bFDCHI2   : bFDCHI2/F                                              *
# *Entries :   535088 : Total  Size=    2144199 bytes  File Size  =    1955654 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.10     *
# *............................................................................*
# *Br   13 :bP        : bP/F                                                   *
# *Entries :   535088 : Total  Size=    2143989 bytes  File Size  =    1880681 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.14     *
# *............................................................................*
# *Br   14 :bETA      : bETA/F                                                 *
# *Entries :   535088 : Total  Size=    2144073 bytes  File Size  =    1834614 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.17     *
# *............................................................................*
# *Br   15 :bPHI      : bPHI/F                                                 *
# *Entries :   535088 : Total  Size=    2144073 bytes  File Size  =    1986853 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   16 :piplusP   : piplusP/F                                              *
# *Entries :   535088 : Total  Size=    2144199 bytes  File Size  =    1911737 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   17 :piplusPT  : piplusPT/F                                             *
# *Entries :   535088 : Total  Size=    2144241 bytes  File Size  =    1903763 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   18 :piplusETA : piplusETA/F                                            *
# *Entries :   535088 : Total  Size=    2144283 bytes  File Size  =    1842877 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.16     *
# *............................................................................*
# *Br   19 :piplusPHI : piplusPHI/F                                            *
# *Entries :   535088 : Total  Size=    2144283 bytes  File Size  =    1985098 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   20 :piminusP  : piminusP/F                                             *
# *Entries :   535088 : Total  Size=    2144241 bytes  File Size  =    1911736 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   21 :piminusPT : piminusPT/F                                            *
# *Entries :   535088 : Total  Size=    2144283 bytes  File Size  =    1903632 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   22 :piminusETA : piminusETA/F                                          *
# *Entries :   535088 : Total  Size=    2144325 bytes  File Size  =    1842877 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.16     *
# *............................................................................*
# *Br   23 :piminusPHI : piminusPHI/F                                          *
# *Entries :   535088 : Total  Size=    2144325 bytes  File Size  =    1984579 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   24 :piplusDLLKPI : piplusDLLKPI/F                                      *
# *Entries :   535088 : Total  Size=    2144409 bytes  File Size  =    1908682 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   25 :piplusDLLPPI : piplusDLLPPI/F                                      *
# *Entries :   535088 : Total  Size=    2144409 bytes  File Size  =    1907313 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   26 :piminusDLLKPI : piminusDLLKPI/F                                    *
# *Entries :   535088 : Total  Size=    2144451 bytes  File Size  =    1908732 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   27 :piminusDLLPPI : piminusDLLPPI/F                                    *
# *Entries :   535088 : Total  Size=    2144451 bytes  File Size  =    1907242 *
# *Baskets :       38 : Basket Size=    1184256 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   28 :mass      : mass/F                                                 *
# *Entries :   535088 : Total  Size=    2144073 bytes  File Size  =    1744855 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   1.23     *
# *............................................................................*
# *Br   29 :tag       : tag/I                                                  *
# *Entries :   535088 : Total  Size=    2144031 bytes  File Size  =     228321 *
# *Baskets :       38 : Basket Size=    1183744 bytes  Compression=   9.39     *
# *............................................................................*
#                          : Booking "BDT" of type "BDT" from dataset/weights/TMVAClassification_BDT.weights.xml.
#                          : Reading weight file: dataset/weights/TMVAClassification_BDT.weights.xml
# <HEADER> DataSetInfo              : [Default] : Added class "Signal"
# <HEADER> DataSetInfo              : [Default] : Added class "Background"
#                          : Booked classifier "BDT" of type: "BDT"
#                          : Rebuilding Dataset Default
